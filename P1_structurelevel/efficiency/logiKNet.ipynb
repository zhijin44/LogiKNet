# %%
import torch
import numpy as np
import pandas as pd
import torch.nn.functional as F
import os

# %%
def load_csv_data(input_folder: str,
                  train_fname: str,
                  test_fname: str):
    """
    Reads train & test CSVs from disk.
    
    Returns:
      train_df, test_df (both pandas.DataFrame)
    """
    train_path = os.path.join(input_folder, train_fname)
    test_path  = os.path.join(input_folder, test_fname)
    train_df = pd.read_csv(train_path)
    test_df  = pd.read_csv(test_path)
    return train_df, test_df

def extract_features_labels(df: pd.DataFrame):
    """
    Splits a DataFrame into numpy feature array X and label vector y.
    
    The last column is the label.
    """
    X = df.iloc[:, :-1].values
    y = df.iloc[:,  -1].values
    return X, y

# Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load data
input_folder = '/home/zyang44/Github/baseline_cicIOT/P1_structurelevel/efficiency/input_files'
train_fname = 'logiKNet_train_35945.csv'
test_fname = 'logiKNet_test_3994.csv'

train_df, test_df = load_csv_data(input_folder, train_fname, test_fname)
# Extract features and labels   
X_train, y_train = extract_features_labels(train_df)
X_test, y_test = extract_features_labels(test_df)

# dataset = {
#     'train_input': torch.tensor(X_train, dtype=torch.float32, device=device),
#     'train_label': F.one_hot(torch.tensor(y_train, dtype=torch.long, device=device), num_classes=6),
#     'test_input': torch.tensor(X_test, dtype=torch.float32, device=device),
#     'test_label': F.one_hot(torch.tensor(y_test, dtype=torch.long, device=device), num_classes=6)
# }

dataset_numeric = {
    'train_input': torch.tensor(X_train, dtype=torch.float32, device=device),
    'train_label': torch.tensor(y_train, dtype=torch.long, device=device),
    'test_input': torch.tensor(X_test, dtype=torch.float32, device=device),
    'test_label': torch.tensor(y_test, dtype=torch.long, device=device)
}

# %%
# this is a standard PyTorch DataLoader to load the dataset for the training and testing of the model
class DataLoader(object):
    def __init__(self,
                 data,
                 labels,
                 batch_size=1,
                 shuffle=True):
        self.data = data
        self.labels = labels
        self.batch_size = batch_size
        self.shuffle = shuffle

    def __len__(self):
        return int(np.ceil(self.data.shape[0] / self.batch_size))

    def __iter__(self):
        n = self.data.shape[0]
        idxlist = list(range(n))
        if self.shuffle:
            np.random.shuffle(idxlist)

        for _, start_idx in enumerate(range(0, n, self.batch_size)):
            end_idx = min(start_idx + self.batch_size, n)
            data = self.data[idxlist[start_idx:end_idx]]
            labels = self.labels[idxlist[start_idx:end_idx]]
            ############################################################
            # Check if any class is missing in the batch
            # present_classes = np.unique(labels.cpu().numpy())
            # all_classes = np.arange(len(label_mapping))  # Adjust based on number of classes
            # missing_classes = set(all_classes) - set(present_classes)
            #
            # if missing_classes:
            #     print(f"Batch {start_idx // self.batch_size} is missing classes {missing_classes}")
            ############################################################
            yield data, labels


train_loader = DataLoader(
    dataset_numeric['train_input'],
    dataset_numeric['train_label'], 
    batch_size=len(X_train), 
    shuffle=True
    )
test_loader = DataLoader(
    dataset_numeric['test_input'],
    dataset_numeric['test_label'],
    # batch_size=len(X_test), 
    batch_size=1,
    shuffle=False
    )

# %%
class LogitsToPredicate(torch.nn.Module):
    """
    This model has inside a logits model, that is a model which compute logits for the classes given an input example x.
    The idea of this model is to keep logits and probabilities separated. The logits model returns the logits for an example,
    while this model returns the probabilities given the logits model.

    In particular, it takes as input an example x and a class label l. It applies the logits model to x to get the logits.
    Then, it applies a softmax function to get the probabilities per classes. Finally, it returns only the probability related
    to the given class l.
    """

    def __init__(self, logits_model):
        super(LogitsToPredicate, self).__init__()
        self.logits_model = logits_model
        self.softmax = torch.nn.Softmax(dim=1)

    def forward(self, x, l, training=False):
        logits = self.logits_model(x, training=training)
        probs = self.softmax(logits)
        out = torch.sum(probs * l, dim=1)  # 计算并返回与给定类标签l对应的概率值
        return out


class MLP(torch.nn.Module):
    """
    This model returns the logits for the classes given an input example. It does not compute the softmax, so the output
    are not normalized.
    This is done to separate the accuracy computation from the satisfaction level computation. Go through the example
    to understand it.
    """

    def __init__(self, layer_sizes):
        super(MLP, self).__init__()
        self.elu = torch.nn.ELU()
        self.dropout = torch.nn.Dropout(0.2)
        self.linear_layers = torch.nn.ModuleList([torch.nn.Linear(layer_sizes[i - 1], layer_sizes[i])
                                                  for i in range(1, len(layer_sizes))])

    def forward(self, x, training=False):
        """
        Method which defines the forward phase of the neural network for our multi class classification task.
        In particular, it returns the logits for the classes given an input example.

        :param x: the features of the example
        :param training: whether the network is in training mode (dropout applied) or validation mode (dropout not applied)
        :return: logits for example x
        """
        for layer in self.linear_layers[:-1]:
            x = self.elu(layer(x))
            if training:
                x = self.dropout(x)
        logits = self.linear_layers[-1](x)
        return logits


class MultiKANModel(torch.nn.Module):
    def __init__(self, kan):
        """
        Wrap an already built MultKAN instance.
        Args:
            kan: a MultKAN model (which has attributes such as act_fun, symbolic_fun, node_bias, node_scale,
                 subnode_bias, subnode_scale, depth, width, mult_homo, mult_arity, input_id, symbolic_enabled, etc.)
        """
        super(MultiKANModel, self).__init__()
        self.kan = kan

    def forward(self, x, training=False, singularity_avoiding=False, y_th=10.):
        # Select input features according to input_id
        x = x[:, self.kan.input_id.long()]
        # Loop through each layer
        for l in range(self.kan.depth):
            # Get outputs from the numerical branch (KANLayer) of current layer
            x_numerical, preacts, postacts_numerical, postspline = self.kan.act_fun[l](x)
            # Get output from the symbolic branch if enabled
            if self.kan.symbolic_enabled:
                x_symbolic, postacts_symbolic = self.kan.symbolic_fun[l](x, singularity_avoiding=singularity_avoiding, y_th=y_th)
            else:
                x_symbolic = 0.
            # Sum the numerical and symbolic outputs
            x = x_numerical + x_symbolic

            # Subnode affine transformation
            x = self.kan.subnode_scale[l][None, :] * x + self.kan.subnode_bias[l][None, :]

            # Process multiplication nodes
            dim_sum = self.kan.width[l+1][0]
            dim_mult = self.kan.width[l+1][1]
            if dim_mult > 0:
                if self.kan.mult_homo:
                    for i in range(self.kan.mult_arity-1):
                        if i == 0:
                            x_mult = x[:, dim_sum::self.kan.mult_arity] * x[:, dim_sum+1::self.kan.mult_arity]
                        else:
                            x_mult = x_mult * x[:, dim_sum+i+1::self.kan.mult_arity]
                else:
                    for j in range(dim_mult):
                        acml_id = dim_sum + int(np.sum(self.kan.mult_arity[l+1][:j]))
                        for i in range(self.kan.mult_arity[l+1][j]-1):
                            if i == 0:
                                x_mult_j = x[:, [acml_id]] * x[:, [acml_id+1]]
                            else:
                                x_mult_j = x_mult_j * x[:, [acml_id+i+1]]
                        if j == 0:
                            x_mult = x_mult_j
                        else:
                            x_mult = torch.cat([x_mult, x_mult_j], dim=1)
                # Concatenate sum and mult parts
                x = torch.cat([x[:, :dim_sum], x_mult], dim=1)

            # Node affine transformation
            x = self.kan.node_scale[l][None, :] * x + self.kan.node_bias[l][None, :]

        # Final x corresponds to the logits output of the whole model
        return x

# %%
def compute_accuracy(loader, model):
    total_correct = 0
    total_samples = 0
    for data, labels in loader:
        logits = model(data)
        preds = torch.argmax(logits, dim=1)
        total_correct += (preds == labels).sum()
        total_samples += labels.numel()
    return total_correct.float() / total_samples


def save_model(model, model_save_folder, model_name):
    """
    Save the model to disk.
    """
    torch.save(model.state_dict(), os.path.join(model_save_folder, model_name))

    print(f"Model saved to {os.path.join(model_save_folder, model_name)}")


model_state_folder = '/home/zyang44/Github/baseline_cicIOT/P1_structurelevel/efficiency/model_weights'

# %% [markdown]
# **MLP with CrossEntropyLoss**

# %%
#  Define the MLP predicate
mlp = MLP(layer_sizes=(18, 10, 6)).to(device)

# MLP with standard loss fn 
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(mlp.parameters(), lr=0.001)

# Train the model
for epoch in range(401):
    for data, labels in train_loader:               # iterate batches
        optimizer.zero_grad()
        logits = mlp(data, training=True)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
    # test
    acc = compute_accuracy(test_loader, mlp)
    print(f"Epoch {epoch}, Loss: {loss.item()}, Test accuracy: {acc.item()}")

# Save the model
save_model(mlp, model_state_folder, 'mlp.pt')
# Out:
# Epoch 0, Loss: 1.8321869373321533, Test accuracy: 0.22033049166202545
# Epoch 1, Loss: 1.8269691467285156, Test accuracy: 0.22258387506008148
# Epoch 2, Loss: 1.8208402395248413, Test accuracy: 0.2248372584581375
# Epoch 3, Loss: 1.8149583339691162, Test accuracy: 0.2265898883342743
# Epoch 4, Loss: 1.8083497285842896, Test accuracy: 0.22934401035308838
# Epoch 5, Loss: 1.8035719394683838, Test accuracy: 0.2315973937511444
# Epoch 6, Loss: 1.7972102165222168, Test accuracy: 0.2343515306711197
# Epoch 7, Loss: 1.7936214208602905, Test accuracy: 0.23710565268993378
# Epoch 8, Loss: 1.787880539894104, Test accuracy: 0.23960942029953003
# Epoch 9, Loss: 1.7805042266845703, Test accuracy: 0.24236354231834412
# Epoch 10, Loss: 1.7773271799087524, Test accuracy: 0.24436655640602112
# Epoch 11, Loss: 1.7715272903442383, Test accuracy: 0.24636955559253693
# Epoch 12, Loss: 1.767098307609558, Test accuracy: 0.24862293899059296
# Epoch 13, Loss: 1.761338472366333, Test accuracy: 0.25137707591056824
# Epoch 14, Loss: 1.7561041116714478, Test accuracy: 0.25338006019592285
# Epoch 15, Loss: 1.7515865564346313, Test accuracy: 0.25538307428359985
# Epoch 16, Loss: 1.7486814260482788, Test accuracy: 0.25838759541511536
# Epoch 17, Loss: 1.7416507005691528, Test accuracy: 0.262643963098526
# Epoch 18, Loss: 1.7390103340148926, Test accuracy: 0.26715072989463806
# Epoch 377, Loss: 1.00678288936615, Test accuracy: 0.6141712665557861
# Epoch 378, Loss: 1.005532145500183, Test accuracy: 0.6141712665557861
# Epoch 379, Loss: 1.0078421831130981, Test accuracy: 0.6141712665557861
# Epoch 380, Loss: 1.0047454833984375, Test accuracy: 0.6141712665557861
# Epoch 381, Loss: 1.0043764114379883, Test accuracy: 0.6144216060638428
# Epoch 382, Loss: 1.0051732063293457, Test accuracy: 0.6144216060638428
# Epoch 383, Loss: 1.0013175010681152, Test accuracy: 0.6141712665557861
# Epoch 384, Loss: 1.0041661262512207, Test accuracy: 0.6146720051765442
# Epoch 385, Loss: 1.0005970001220703, Test accuracy: 0.6144216060638428
# Epoch 386, Loss: 1.0038752555847168, Test accuracy: 0.6141712665557861
# Epoch 387, Loss: 0.9999931454658508, Test accuracy: 0.6144216060638428
# Epoch 388, Loss: 0.9991841912269592, Test accuracy: 0.6144216060638428
# Epoch 389, Loss: 1.0003058910369873, Test accuracy: 0.6144216060638428
# Epoch 390, Loss: 0.9987197518348694, Test accuracy: 0.6144216060638428
# Epoch 391, Loss: 0.9949262738227844, Test accuracy: 0.6144216060638428
# Epoch 392, Loss: 0.9964892268180847, Test accuracy: 0.6144216060638428
# Epoch 393, Loss: 0.9922842383384705, Test accuracy: 0.6146720051765442
# Epoch 394, Loss: 0.9899090528488159, Test accuracy: 0.6149224042892456
# Epoch 395, Loss: 0.9943704009056091, Test accuracy: 0.6149224042892456
# Epoch 396, Loss: 0.9895214438438416, Test accuracy: 0.6149224042892456
# Epoch 397, Loss: 0.9885925054550171, Test accuracy: 0.6151727437973022
# Epoch 398, Loss: 0.9895531535148621, Test accuracy: 0.6151727437973022
# Epoch 399, Loss: 0.9858949184417725, Test accuracy: 0.6151727437973022
# Epoch 400, Loss: 0.9865071773529053, Test accuracy: 0.6156734824180603
# Model saved to /home/zyang44/Github/baseline_cicIOT/P1_structurelevel/efficiency/model_weights/mlp.pt

# %%
def load_model_state(infer_model, model_save_folder, model_name):
    """
    Load the model from disk.
    """
    checkpoint = torch.load(os.path.join(model_save_folder, model_name), 
                            map_location=device)
    infer_model.load_state_dict(checkpoint)
    infer_model.eval()
    return infer_model

# Load the model
mlp_infer = MLP(layer_sizes=(18, 10, 6)).to(device)
mlp_infer = load_model_state(mlp_infer, model_state_folder, 'mlp.pt')
# Test the model
with torch.no_grad():
    for data, labels in test_loader:
        logits = mlp_infer(data)
        preds = torch.argmax(logits, dim=1)
        print(f"Predictions: {preds}, Labels: {labels}")
        
        mlp_infer_acc = compute_accuracy(test_loader, mlp_infer)
        print(f"Test accuracy of the loaded model: {mlp_infer_acc.item()}")
        break

# %% [markdown]
# **LTN utils setup**

# %%
import ltn
import ltn.fuzzy_ops
import torch
import os
from kan import KAN

# define the connectives, quantifiers, and the SatAgg
Not = ltn.Connective(ltn.fuzzy_ops.NotStandard())
And = ltn.Connective(ltn.fuzzy_ops.AndProd())   # And = ltn.Connective(custom_fuzzy_ops.AndProd())
Or = ltn.Connective(ltn.fuzzy_ops.OrProbSum())
Forall = ltn.Quantifier(ltn.fuzzy_ops.AggregPMeanError(p=2), quantifier="f")
Exists = ltn.Quantifier(ltn.fuzzy_ops.AggregPMean(p=2), quantifier="e")
Implies = ltn.Connective(ltn.fuzzy_ops.ImpliesReichenbach())
SatAgg = ltn.fuzzy_ops.SatAgg()

# define ltn constants
l_MQTT_DDoS_Connect_Flood = ltn.Constant(torch.tensor([1, 0, 0, 0, 0, 0]))
l_MQTT_DDoS_Publish_Flood = ltn.Constant(torch.tensor([0, 1, 0, 0, 0, 0]))
l_MQTT_DoS_Connect_Flood = ltn.Constant(torch.tensor([0, 0, 1, 0, 0, 0]))
l_MQTT_DoS_Publish_Flood = ltn.Constant(torch.tensor([0, 0, 0, 1, 0, 0]))
l_MQTT_Malformed_Data = ltn.Constant(torch.tensor([0, 0, 0, 0, 1, 0]))
l_Benign = ltn.Constant(torch.tensor([0, 0, 0, 0, 0, 1]))

# %% [markdown]
# **LogiK-mlp**
# : MLP with LTN

# %%
def compute_sat_levels(loader, P):
	sat_level  = 0
	for data, labels in loader:
		x = ltn.Variable("x", data)
		x_MQTT_DDoS_Connect_Flood = ltn.Variable("x_MQTT_DDoS_Connect_Flood", data[labels == 0])
		x_MQTT_DDoS_Publish_Flood = ltn.Variable("x_MQTT_DDoS_Publish_Flood", data[labels == 1])
		x_MQTT_DoS_Connect_Flood = ltn.Variable("x_MQTT_DoS_Connect_Flood", data[labels == 2])
		x_MQTT_DoS_Publish_Flood = ltn.Variable("x_MQTT_DoS_Publish_Flood", data[labels == 3])
		x_MQTT_Malformed_Data = ltn.Variable("x_MQTT_Malformed_Data", data[labels == 4])
		x_Benign = ltn.Variable("x_Benign", data[labels == 5])

		sat_level = SatAgg(
			Forall(x_MQTT_DDoS_Connect_Flood, P(x_MQTT_DDoS_Connect_Flood, l_MQTT_DDoS_Connect_Flood)),
			Forall(x_MQTT_DDoS_Publish_Flood, P(x_MQTT_DDoS_Publish_Flood, l_MQTT_DDoS_Publish_Flood)),
			Forall(x_MQTT_DoS_Connect_Flood, P(x_MQTT_DoS_Connect_Flood, l_MQTT_DoS_Connect_Flood)),
			Forall(x_MQTT_DoS_Publish_Flood, P(x_MQTT_DoS_Publish_Flood, l_MQTT_DoS_Publish_Flood)),
			Forall(x_MQTT_Malformed_Data, P(x_MQTT_Malformed_Data, l_MQTT_Malformed_Data)),
			Forall(x_Benign, P(x_Benign, l_Benign))
		)
	return sat_level

mlp = MLP(layer_sizes=(18, 10, 6)).to(device)
P_mlp = ltn.Predicate(LogitsToPredicate(mlp))

optimizer = torch.optim.Adam(P_mlp.parameters(), lr=0.001)

# Train the model
for epoch in range(801):             
	optimizer.zero_grad()
	sat_mlp = compute_sat_levels(train_loader, P_mlp)
	loss = 1. - sat_mlp
	loss.backward()
	optimizer.step()
	train_loss_mlp  = loss.item()
	
	# test
	test_acc_mlp = compute_accuracy(test_loader, mlp)
	test_sat_mlp = compute_sat_levels(test_loader, P_mlp)
	print(f"Epoch {epoch} | Logic-MLP (loss/acc/sat): {train_loss_mlp:.3f}/{test_acc_mlp:.3f}/{sat_mlp:.3f}({test_sat_mlp:.3f})")

print("Training finished.")

# save the models as .pt files
save_model(mlp, model_state_folder, 'logic_mlp.pt')
# Out:
# Epoch 0 | Logic-MLP (loss/acc/sat): 0.840/0.156/0.160(0.161)
# Epoch 1 | Logic-MLP (loss/acc/sat): 0.840/0.153/0.160(0.161)
# Epoch 2 | Logic-MLP (loss/acc/sat): 0.839/0.147/0.161(0.162)
# Epoch 3 | Logic-MLP (loss/acc/sat): 0.838/0.136/0.162(0.163)
# Epoch 4 | Logic-MLP (loss/acc/sat): 0.837/0.141/0.163(0.164)
# Epoch 5 | Logic-MLP (loss/acc/sat): 0.836/0.263/0.164(0.165)
# Epoch 6 | Logic-MLP (loss/acc/sat): 0.836/0.264/0.164(0.166)
# Epoch 7 | Logic-MLP (loss/acc/sat): 0.835/0.263/0.165(0.167)
# Epoch 8 | Logic-MLP (loss/acc/sat): 0.834/0.264/0.166(0.167)
# Epoch 9 | Logic-MLP (loss/acc/sat): 0.833/0.264/0.167(0.168)
# Epoch 10 | Logic-MLP (loss/acc/sat): 0.832/0.263/0.168(0.169)
# Epoch 11 | Logic-MLP (loss/acc/sat): 0.831/0.263/0.169(0.170)
# Epoch 12 | Logic-MLP (loss/acc/sat): 0.830/0.263/0.170(0.171)
# Epoch 13 | Logic-MLP (loss/acc/sat): 0.830/0.263/0.170(0.172)
# Epoch 14 | Logic-MLP (loss/acc/sat): 0.829/0.263/0.171(0.173)
# Epoch 15 | Logic-MLP (loss/acc/sat): 0.828/0.263/0.172(0.174)
# Epoch 16 | Logic-MLP (loss/acc/sat): 0.827/0.263/0.173(0.175)
# Epoch 17 | Logic-MLP (loss/acc/sat): 0.826/0.263/0.174(0.175)
# Epoch 18 | Logic-MLP (loss/acc/sat): 0.825/0.263/0.175(0.176)
# Epoch 19 | Logic-MLP (loss/acc/sat): 0.824/0.263/0.176(0.177)
# Epoch 20 | Logic-MLP (loss/acc/sat): 0.823/0.263/0.177(0.178)
# Epoch 21 | Logic-MLP (loss/acc/sat): 0.823/0.263/0.177(0.179)
# Epoch 22 | Logic-MLP (loss/acc/sat): 0.822/0.263/0.178(0.180)
# Epoch 23 | Logic-MLP (loss/acc/sat): 0.821/0.263/0.179(0.181)
# Epoch 24 | Logic-MLP (loss/acc/sat): 0.820/0.263/0.180(0.182)
# Epoch 25 | Logic-MLP (loss/acc/sat): 0.819/0.263/0.181(0.183)
# Epoch 26 | Logic-MLP (loss/acc/sat): 0.818/0.263/0.182(0.184)
# Epoch 27 | Logic-MLP (loss/acc/sat): 0.817/0.263/0.183(0.185)
# Epoch 28 | Logic-MLP (loss/acc/sat): 0.816/0.263/0.184(0.186)
# Epoch 29 | Logic-MLP (loss/acc/sat): 0.815/0.263/0.185(0.187)
# Epoch 30 | Logic-MLP (loss/acc/sat): 0.814/0.264/0.186(0.188)
# Epoch 31 | Logic-MLP (loss/acc/sat): 0.813/0.264/0.187(0.189)
# Epoch 32 | Logic-MLP (loss/acc/sat): 0.812/0.265/0.188(0.190)
# Epoch 33 | Logic-MLP (loss/acc/sat): 0.811/0.265/0.189(0.191)
# Epoch 34 | Logic-MLP (loss/acc/sat): 0.810/0.266/0.190(0.192)
# Epoch 35 | Logic-MLP (loss/acc/sat): 0.809/0.267/0.191(0.193)
# Epoch 36 | Logic-MLP (loss/acc/sat): 0.808/0.267/0.192(0.194)
# Epoch 37 | Logic-MLP (loss/acc/sat): 0.807/0.268/0.193(0.195)
# Epoch 38 | Logic-MLP (loss/acc/sat): 0.806/0.268/0.194(0.196)
# Epoch 39 | Logic-MLP (loss/acc/sat): 0.805/0.270/0.195(0.197)
# Epoch 40 | Logic-MLP (loss/acc/sat): 0.804/0.271/0.196(0.198)
# Epoch 41 | Logic-MLP (loss/acc/sat): 0.803/0.271/0.197(0.199)
# Epoch 42 | Logic-MLP (loss/acc/sat): 0.802/0.271/0.198(0.200)
# Epoch 43 | Logic-MLP (loss/acc/sat): 0.801/0.273/0.199(0.201)
# Epoch 44 | Logic-MLP (loss/acc/sat): 0.800/0.273/0.200(0.202)
# Epoch 45 | Logic-MLP (loss/acc/sat): 0.799/0.273/0.201(0.203)
# Epoch 46 | Logic-MLP (loss/acc/sat): 0.798/0.273/0.202(0.204)
# Epoch 47 | Logic-MLP (loss/acc/sat): 0.797/0.273/0.203(0.205)
# Epoch 48 | Logic-MLP (loss/acc/sat): 0.796/0.274/0.204(0.207)
# Epoch 49 | Logic-MLP (loss/acc/sat): 0.795/0.274/0.205(0.208)
# Epoch 50 | Logic-MLP (loss/acc/sat): 0.794/0.275/0.206(0.209)
# Epoch 51 | Logic-MLP (loss/acc/sat): 0.793/0.276/0.207(0.210)
# Epoch 52 | Logic-MLP (loss/acc/sat): 0.792/0.277/0.208(0.211)
# Epoch 53 | Logic-MLP (loss/acc/sat): 0.791/0.279/0.209(0.212)
# Epoch 54 | Logic-MLP (loss/acc/sat): 0.790/0.280/0.210(0.213)
# Epoch 55 | Logic-MLP (loss/acc/sat): 0.789/0.283/0.211(0.214)
# Epoch 56 | Logic-MLP (loss/acc/sat): 0.788/0.285/0.212(0.215)
# Epoch 57 | Logic-MLP (loss/acc/sat): 0.786/0.289/0.214(0.216)
# Epoch 58 | Logic-MLP (loss/acc/sat): 0.785/0.294/0.215(0.217)
# Epoch 59 | Logic-MLP (loss/acc/sat): 0.784/0.297/0.216(0.218)
# Epoch 60 | Logic-MLP (loss/acc/sat): 0.783/0.300/0.217(0.219)
# Epoch 61 | Logic-MLP (loss/acc/sat): 0.782/0.306/0.218(0.221)
# Epoch 62 | Logic-MLP (loss/acc/sat): 0.781/0.309/0.219(0.222)
# Epoch 63 | Logic-MLP (loss/acc/sat): 0.780/0.314/0.220(0.223)
# Epoch 64 | Logic-MLP (loss/acc/sat): 0.779/0.318/0.221(0.224)
# Epoch 65 | Logic-MLP (loss/acc/sat): 0.778/0.323/0.222(0.225)
# Epoch 66 | Logic-MLP (loss/acc/sat): 0.777/0.330/0.223(0.226)
# Epoch 67 | Logic-MLP (loss/acc/sat): 0.776/0.338/0.224(0.227)
# Epoch 68 | Logic-MLP (loss/acc/sat): 0.774/0.345/0.226(0.228)
# Epoch 69 | Logic-MLP (loss/acc/sat): 0.773/0.348/0.227(0.229)
# Epoch 70 | Logic-MLP (loss/acc/sat): 0.772/0.354/0.228(0.231)
# Epoch 71 | Logic-MLP (loss/acc/sat): 0.771/0.356/0.229(0.232)
# Epoch 72 | Logic-MLP (loss/acc/sat): 0.770/0.358/0.230(0.233)
# Epoch 73 | Logic-MLP (loss/acc/sat): 0.769/0.362/0.231(0.234)
# Epoch 74 | Logic-MLP (loss/acc/sat): 0.768/0.366/0.232(0.235)
# Epoch 75 | Logic-MLP (loss/acc/sat): 0.767/0.369/0.233(0.236)
# Epoch 76 | Logic-MLP (loss/acc/sat): 0.766/0.371/0.234(0.237)
# Epoch 77 | Logic-MLP (loss/acc/sat): 0.765/0.373/0.235(0.238)
# Epoch 78 | Logic-MLP (loss/acc/sat): 0.764/0.373/0.236(0.239)
# Epoch 79 | Logic-MLP (loss/acc/sat): 0.762/0.376/0.238(0.240)
# Epoch 80 | Logic-MLP (loss/acc/sat): 0.761/0.380/0.239(0.241)
# Epoch 81 | Logic-MLP (loss/acc/sat): 0.760/0.382/0.240(0.243)
# Epoch 82 | Logic-MLP (loss/acc/sat): 0.759/0.383/0.241(0.244)
# Epoch 83 | Logic-MLP (loss/acc/sat): 0.758/0.384/0.242(0.245)
# Epoch 84 | Logic-MLP (loss/acc/sat): 0.757/0.385/0.243(0.246)
# Epoch 85 | Logic-MLP (loss/acc/sat): 0.756/0.386/0.244(0.247)
# Epoch 86 | Logic-MLP (loss/acc/sat): 0.755/0.387/0.245(0.248)
# Epoch 87 | Logic-MLP (loss/acc/sat): 0.754/0.389/0.246(0.249)
# Epoch 88 | Logic-MLP (loss/acc/sat): 0.753/0.390/0.247(0.250)
# Epoch 89 | Logic-MLP (loss/acc/sat): 0.752/0.392/0.248(0.251)
# Epoch 90 | Logic-MLP (loss/acc/sat): 0.751/0.394/0.249(0.252)
# Epoch 91 | Logic-MLP (loss/acc/sat): 0.750/0.394/0.250(0.253)
# Epoch 92 | Logic-MLP (loss/acc/sat): 0.749/0.394/0.251(0.254)
# Epoch 93 | Logic-MLP (loss/acc/sat): 0.748/0.394/0.252(0.255)
# Epoch 94 | Logic-MLP (loss/acc/sat): 0.747/0.395/0.253(0.256)
# Epoch 95 | Logic-MLP (loss/acc/sat): 0.746/0.396/0.254(0.257)
# Epoch 96 | Logic-MLP (loss/acc/sat): 0.745/0.396/0.255(0.258)
# Epoch 97 | Logic-MLP (loss/acc/sat): 0.744/0.398/0.256(0.259)
# Epoch 98 | Logic-MLP (loss/acc/sat): 0.743/0.399/0.257(0.260)
# Epoch 99 | Logic-MLP (loss/acc/sat): 0.742/0.400/0.258(0.261)
# Epoch 100 | Logic-MLP (loss/acc/sat): 0.741/0.402/0.259(0.262)
# Epoch 101 | Logic-MLP (loss/acc/sat): 0.740/0.403/0.260(0.263)
# Epoch 102 | Logic-MLP (loss/acc/sat): 0.739/0.404/0.261(0.264)
# Epoch 103 | Logic-MLP (loss/acc/sat): 0.738/0.406/0.262(0.265)
# Epoch 104 | Logic-MLP (loss/acc/sat): 0.737/0.407/0.263(0.266)
# Epoch 105 | Logic-MLP (loss/acc/sat): 0.736/0.408/0.264(0.267)
# Epoch 106 | Logic-MLP (loss/acc/sat): 0.736/0.408/0.264(0.267)
# Epoch 107 | Logic-MLP (loss/acc/sat): 0.735/0.411/0.265(0.268)
# Epoch 108 | Logic-MLP (loss/acc/sat): 0.734/0.411/0.266(0.269)
# Epoch 109 | Logic-MLP (loss/acc/sat): 0.733/0.413/0.267(0.270)
# Epoch 110 | Logic-MLP (loss/acc/sat): 0.732/0.413/0.268(0.271)
# Epoch 111 | Logic-MLP (loss/acc/sat): 0.731/0.415/0.269(0.272)
# Epoch 112 | Logic-MLP (loss/acc/sat): 0.730/0.416/0.270(0.273)
# Epoch 113 | Logic-MLP (loss/acc/sat): 0.729/0.417/0.271(0.274)
# Epoch 114 | Logic-MLP (loss/acc/sat): 0.729/0.417/0.271(0.275)
# Epoch 115 | Logic-MLP (loss/acc/sat): 0.728/0.418/0.272(0.275)
# Epoch 116 | Logic-MLP (loss/acc/sat): 0.727/0.419/0.273(0.276)
# Epoch 117 | Logic-MLP (loss/acc/sat): 0.726/0.420/0.274(0.277)
# Epoch 118 | Logic-MLP (loss/acc/sat): 0.725/0.421/0.275(0.278)
# Epoch 119 | Logic-MLP (loss/acc/sat): 0.724/0.422/0.276(0.279)
# Epoch 120 | Logic-MLP (loss/acc/sat): 0.724/0.423/0.276(0.280)
# Epoch 121 | Logic-MLP (loss/acc/sat): 0.723/0.424/0.277(0.281)
# Epoch 122 | Logic-MLP (loss/acc/sat): 0.722/0.425/0.278(0.281)
# Epoch 123 | Logic-MLP (loss/acc/sat): 0.721/0.427/0.279(0.282)
# Epoch 124 | Logic-MLP (loss/acc/sat): 0.720/0.428/0.280(0.283)
# Epoch 125 | Logic-MLP (loss/acc/sat): 0.719/0.428/0.281(0.284)
# Epoch 126 | Logic-MLP (loss/acc/sat): 0.719/0.429/0.281(0.285)
# Epoch 127 | Logic-MLP (loss/acc/sat): 0.718/0.430/0.282(0.286)
# Epoch 128 | Logic-MLP (loss/acc/sat): 0.717/0.431/0.283(0.286)
# Epoch 129 | Logic-MLP (loss/acc/sat): 0.716/0.432/0.284(0.287)
# Epoch 130 | Logic-MLP (loss/acc/sat): 0.716/0.433/0.284(0.288)
# Epoch 131 | Logic-MLP (loss/acc/sat): 0.715/0.433/0.285(0.289)
# Epoch 132 | Logic-MLP (loss/acc/sat): 0.714/0.434/0.286(0.289)
# Epoch 133 | Logic-MLP (loss/acc/sat): 0.713/0.434/0.287(0.290)
# Epoch 134 | Logic-MLP (loss/acc/sat): 0.712/0.435/0.288(0.291)
# Epoch 135 | Logic-MLP (loss/acc/sat): 0.712/0.435/0.288(0.292)
# Epoch 136 | Logic-MLP (loss/acc/sat): 0.711/0.436/0.289(0.293)
# Epoch 137 | Logic-MLP (loss/acc/sat): 0.710/0.437/0.290(0.293)
# Epoch 138 | Logic-MLP (loss/acc/sat): 0.710/0.437/0.290(0.294)
# Epoch 139 | Logic-MLP (loss/acc/sat): 0.709/0.438/0.291(0.295)
# Epoch 140 | Logic-MLP (loss/acc/sat): 0.708/0.439/0.292(0.296)
# Epoch 141 | Logic-MLP (loss/acc/sat): 0.707/0.439/0.293(0.296)
# Epoch 142 | Logic-MLP (loss/acc/sat): 0.707/0.439/0.293(0.297)
# Epoch 143 | Logic-MLP (loss/acc/sat): 0.706/0.439/0.294(0.298)
# Epoch 144 | Logic-MLP (loss/acc/sat): 0.705/0.439/0.295(0.299)
# Epoch 145 | Logic-MLP (loss/acc/sat): 0.704/0.440/0.296(0.299)
# Epoch 146 | Logic-MLP (loss/acc/sat): 0.704/0.441/0.296(0.300)
# Epoch 147 | Logic-MLP (loss/acc/sat): 0.703/0.441/0.297(0.301)
# Epoch 148 | Logic-MLP (loss/acc/sat): 0.702/0.442/0.298(0.301)
# Epoch 149 | Logic-MLP (loss/acc/sat): 0.702/0.444/0.298(0.302)
# Epoch 150 | Logic-MLP (loss/acc/sat): 0.701/0.445/0.299(0.303)
# Epoch 151 | Logic-MLP (loss/acc/sat): 0.700/0.446/0.300(0.304)
# Epoch 152 | Logic-MLP (loss/acc/sat): 0.699/0.447/0.301(0.304)
# Epoch 153 | Logic-MLP (loss/acc/sat): 0.699/0.448/0.301(0.305)
# Epoch 154 | Logic-MLP (loss/acc/sat): 0.698/0.449/0.302(0.306)
# Epoch 155 | Logic-MLP (loss/acc/sat): 0.697/0.451/0.303(0.306)
# Epoch 156 | Logic-MLP (loss/acc/sat): 0.697/0.454/0.303(0.307)
# Epoch 157 | Logic-MLP (loss/acc/sat): 0.696/0.455/0.304(0.308)
# Epoch 158 | Logic-MLP (loss/acc/sat): 0.695/0.458/0.305(0.308)
# Epoch 159 | Logic-MLP (loss/acc/sat): 0.695/0.460/0.305(0.309)
# Epoch 160 | Logic-MLP (loss/acc/sat): 0.694/0.464/0.306(0.310)
# Epoch 161 | Logic-MLP (loss/acc/sat): 0.693/0.467/0.307(0.310)
# Epoch 162 | Logic-MLP (loss/acc/sat): 0.693/0.470/0.307(0.311)
# Epoch 163 | Logic-MLP (loss/acc/sat): 0.692/0.470/0.308(0.312)
# Epoch 164 | Logic-MLP (loss/acc/sat): 0.691/0.474/0.309(0.312)
# Epoch 165 | Logic-MLP (loss/acc/sat): 0.691/0.476/0.309(0.313)
# Epoch 166 | Logic-MLP (loss/acc/sat): 0.690/0.481/0.310(0.314)
# Epoch 167 | Logic-MLP (loss/acc/sat): 0.689/0.485/0.311(0.314)
# Epoch 168 | Logic-MLP (loss/acc/sat): 0.689/0.488/0.311(0.315)
# Epoch 169 | Logic-MLP (loss/acc/sat): 0.688/0.491/0.312(0.316)
# Epoch 170 | Logic-MLP (loss/acc/sat): 0.687/0.494/0.313(0.316)
# Epoch 171 | Logic-MLP (loss/acc/sat): 0.687/0.496/0.313(0.317)
# Epoch 172 | Logic-MLP (loss/acc/sat): 0.686/0.497/0.314(0.318)
# Epoch 173 | Logic-MLP (loss/acc/sat): 0.685/0.498/0.315(0.318)
# Epoch 174 | Logic-MLP (loss/acc/sat): 0.685/0.499/0.315(0.319)
# Epoch 175 | Logic-MLP (loss/acc/sat): 0.684/0.499/0.316(0.320)
# Epoch 176 | Logic-MLP (loss/acc/sat): 0.683/0.500/0.317(0.320)
# Epoch 177 | Logic-MLP (loss/acc/sat): 0.683/0.500/0.317(0.321)
# Epoch 178 | Logic-MLP (loss/acc/sat): 0.682/0.501/0.318(0.322)
# Epoch 179 | Logic-MLP (loss/acc/sat): 0.681/0.501/0.319(0.322)
# Epoch 180 | Logic-MLP (loss/acc/sat): 0.681/0.501/0.319(0.323)
# Epoch 181 | Logic-MLP (loss/acc/sat): 0.680/0.501/0.320(0.324)
# Epoch 182 | Logic-MLP (loss/acc/sat): 0.680/0.501/0.320(0.324)
# Epoch 183 | Logic-MLP (loss/acc/sat): 0.679/0.501/0.321(0.325)
# Epoch 184 | Logic-MLP (loss/acc/sat): 0.678/0.501/0.322(0.325)
# Epoch 185 | Logic-MLP (loss/acc/sat): 0.678/0.502/0.322(0.326)
# Epoch 186 | Logic-MLP (loss/acc/sat): 0.677/0.502/0.323(0.327)
# Epoch 187 | Logic-MLP (loss/acc/sat): 0.676/0.503/0.324(0.327)
# Epoch 188 | Logic-MLP (loss/acc/sat): 0.676/0.504/0.324(0.328)
# Epoch 189 | Logic-MLP (loss/acc/sat): 0.675/0.505/0.325(0.328)
# Epoch 190 | Logic-MLP (loss/acc/sat): 0.675/0.505/0.325(0.329)
# Epoch 191 | Logic-MLP (loss/acc/sat): 0.674/0.505/0.326(0.330)
# Epoch 192 | Logic-MLP (loss/acc/sat): 0.673/0.505/0.327(0.330)
# Epoch 193 | Logic-MLP (loss/acc/sat): 0.673/0.507/0.327(0.331)
# Epoch 194 | Logic-MLP (loss/acc/sat): 0.672/0.508/0.328(0.332)
# Epoch 195 | Logic-MLP (loss/acc/sat): 0.672/0.508/0.328(0.332)
# Epoch 196 | Logic-MLP (loss/acc/sat): 0.671/0.508/0.329(0.333)
# Epoch 197 | Logic-MLP (loss/acc/sat): 0.670/0.508/0.330(0.333)
# Epoch 198 | Logic-MLP (loss/acc/sat): 0.670/0.509/0.330(0.334)
# Epoch 199 | Logic-MLP (loss/acc/sat): 0.669/0.510/0.331(0.334)
# Epoch 200 | Logic-MLP (loss/acc/sat): 0.669/0.510/0.331(0.335)
# Epoch 201 | Logic-MLP (loss/acc/sat): 0.668/0.509/0.332(0.336)
# Epoch 202 | Logic-MLP (loss/acc/sat): 0.667/0.510/0.333(0.336)
# Epoch 203 | Logic-MLP (loss/acc/sat): 0.667/0.509/0.333(0.337)
# Epoch 204 | Logic-MLP (loss/acc/sat): 0.666/0.510/0.334(0.337)
# Epoch 205 | Logic-MLP (loss/acc/sat): 0.666/0.510/0.334(0.338)
# Epoch 206 | Logic-MLP (loss/acc/sat): 0.665/0.510/0.335(0.339)
# Epoch 207 | Logic-MLP (loss/acc/sat): 0.665/0.510/0.335(0.339)
# Epoch 208 | Logic-MLP (loss/acc/sat): 0.664/0.511/0.336(0.340)
# Epoch 209 | Logic-MLP (loss/acc/sat): 0.663/0.511/0.337(0.340)
# Epoch 210 | Logic-MLP (loss/acc/sat): 0.663/0.511/0.337(0.341)
# Epoch 211 | Logic-MLP (loss/acc/sat): 0.662/0.511/0.338(0.341)
# Epoch 212 | Logic-MLP (loss/acc/sat): 0.662/0.511/0.338(0.342)
# Epoch 213 | Logic-MLP (loss/acc/sat): 0.661/0.512/0.339(0.343)
# Epoch 214 | Logic-MLP (loss/acc/sat): 0.661/0.512/0.339(0.343)
# Epoch 215 | Logic-MLP (loss/acc/sat): 0.660/0.513/0.340(0.344)
# Epoch 216 | Logic-MLP (loss/acc/sat): 0.660/0.513/0.340(0.344)
# Epoch 217 | Logic-MLP (loss/acc/sat): 0.659/0.513/0.341(0.345)
# Epoch 218 | Logic-MLP (loss/acc/sat): 0.658/0.515/0.342(0.345)
# Epoch 219 | Logic-MLP (loss/acc/sat): 0.658/0.515/0.342(0.346)
# Epoch 220 | Logic-MLP (loss/acc/sat): 0.657/0.516/0.343(0.346)
# Epoch 221 | Logic-MLP (loss/acc/sat): 0.657/0.516/0.343(0.347)
# Epoch 222 | Logic-MLP (loss/acc/sat): 0.656/0.517/0.344(0.347)
# Epoch 223 | Logic-MLP (loss/acc/sat): 0.656/0.517/0.344(0.348)
# Epoch 224 | Logic-MLP (loss/acc/sat): 0.655/0.517/0.345(0.349)
# Epoch 225 | Logic-MLP (loss/acc/sat): 0.655/0.518/0.345(0.349)
# Epoch 226 | Logic-MLP (loss/acc/sat): 0.654/0.520/0.346(0.350)
# Epoch 227 | Logic-MLP (loss/acc/sat): 0.654/0.520/0.346(0.350)
# Epoch 228 | Logic-MLP (loss/acc/sat): 0.653/0.521/0.347(0.351)
# Epoch 229 | Logic-MLP (loss/acc/sat): 0.652/0.521/0.348(0.351)
# Epoch 230 | Logic-MLP (loss/acc/sat): 0.652/0.522/0.348(0.352)
# Epoch 231 | Logic-MLP (loss/acc/sat): 0.651/0.522/0.349(0.352)
# Epoch 232 | Logic-MLP (loss/acc/sat): 0.651/0.523/0.349(0.353)
# Epoch 233 | Logic-MLP (loss/acc/sat): 0.650/0.523/0.350(0.353)
# Epoch 234 | Logic-MLP (loss/acc/sat): 0.650/0.524/0.350(0.354)
# Epoch 235 | Logic-MLP (loss/acc/sat): 0.649/0.525/0.351(0.354)
# Epoch 236 | Logic-MLP (loss/acc/sat): 0.649/0.525/0.351(0.355)
# Epoch 237 | Logic-MLP (loss/acc/sat): 0.648/0.525/0.352(0.355)
# Epoch 238 | Logic-MLP (loss/acc/sat): 0.648/0.525/0.352(0.356)
# Epoch 239 | Logic-MLP (loss/acc/sat): 0.647/0.525/0.353(0.356)
# Epoch 240 | Logic-MLP (loss/acc/sat): 0.647/0.526/0.353(0.357)
# Epoch 241 | Logic-MLP (loss/acc/sat): 0.646/0.526/0.354(0.357)
# Epoch 242 | Logic-MLP (loss/acc/sat): 0.646/0.526/0.354(0.358)
# Epoch 243 | Logic-MLP (loss/acc/sat): 0.645/0.526/0.355(0.358)
# Epoch 244 | Logic-MLP (loss/acc/sat): 0.645/0.526/0.355(0.359)
# Epoch 245 | Logic-MLP (loss/acc/sat): 0.644/0.525/0.356(0.359)
# Epoch 246 | Logic-MLP (loss/acc/sat): 0.644/0.525/0.356(0.360)
# Epoch 247 | Logic-MLP (loss/acc/sat): 0.643/0.526/0.357(0.360)
# Epoch 248 | Logic-MLP (loss/acc/sat): 0.643/0.526/0.357(0.361)
# Epoch 249 | Logic-MLP (loss/acc/sat): 0.642/0.526/0.358(0.361)
# Epoch 250 | Logic-MLP (loss/acc/sat): 0.642/0.526/0.358(0.362)
# Epoch 251 | Logic-MLP (loss/acc/sat): 0.641/0.527/0.359(0.362)
# Epoch 252 | Logic-MLP (loss/acc/sat): 0.641/0.527/0.359(0.363)
# Epoch 253 | Logic-MLP (loss/acc/sat): 0.640/0.528/0.360(0.363)
# Epoch 254 | Logic-MLP (loss/acc/sat): 0.640/0.528/0.360(0.364)
# Epoch 255 | Logic-MLP (loss/acc/sat): 0.639/0.528/0.361(0.364)
# Epoch 256 | Logic-MLP (loss/acc/sat): 0.639/0.528/0.361(0.365)
# Epoch 257 | Logic-MLP (loss/acc/sat): 0.638/0.528/0.362(0.365)
# Epoch 258 | Logic-MLP (loss/acc/sat): 0.638/0.529/0.362(0.366)
# Epoch 259 | Logic-MLP (loss/acc/sat): 0.638/0.528/0.362(0.366)
# Epoch 260 | Logic-MLP (loss/acc/sat): 0.637/0.529/0.363(0.366)
# Epoch 261 | Logic-MLP (loss/acc/sat): 0.637/0.529/0.363(0.367)
# Epoch 262 | Logic-MLP (loss/acc/sat): 0.636/0.530/0.364(0.367)
# Epoch 263 | Logic-MLP (loss/acc/sat): 0.636/0.529/0.364(0.368)
# Epoch 264 | Logic-MLP (loss/acc/sat): 0.635/0.530/0.365(0.368)
# Epoch 265 | Logic-MLP (loss/acc/sat): 0.635/0.530/0.365(0.369)
# Epoch 266 | Logic-MLP (loss/acc/sat): 0.634/0.530/0.366(0.369)
# Epoch 267 | Logic-MLP (loss/acc/sat): 0.634/0.530/0.366(0.370)
# Epoch 268 | Logic-MLP (loss/acc/sat): 0.633/0.530/0.367(0.370)
# Epoch 269 | Logic-MLP (loss/acc/sat): 0.633/0.532/0.367(0.371)
# Epoch 270 | Logic-MLP (loss/acc/sat): 0.633/0.531/0.367(0.371)
# Epoch 271 | Logic-MLP (loss/acc/sat): 0.632/0.531/0.368(0.371)
# Epoch 272 | Logic-MLP (loss/acc/sat): 0.632/0.531/0.368(0.372)
# Epoch 273 | Logic-MLP (loss/acc/sat): 0.631/0.531/0.369(0.372)
# Epoch 274 | Logic-MLP (loss/acc/sat): 0.631/0.531/0.369(0.373)
# Epoch 275 | Logic-MLP (loss/acc/sat): 0.630/0.532/0.370(0.373)
# Epoch 276 | Logic-MLP (loss/acc/sat): 0.630/0.531/0.370(0.374)
# Epoch 277 | Logic-MLP (loss/acc/sat): 0.630/0.532/0.370(0.374)
# Epoch 278 | Logic-MLP (loss/acc/sat): 0.629/0.532/0.371(0.374)
# Epoch 279 | Logic-MLP (loss/acc/sat): 0.629/0.532/0.371(0.375)
# Epoch 280 | Logic-MLP (loss/acc/sat): 0.628/0.533/0.372(0.375)
# Epoch 281 | Logic-MLP (loss/acc/sat): 0.628/0.533/0.372(0.376)
# Epoch 282 | Logic-MLP (loss/acc/sat): 0.627/0.533/0.373(0.376)
# Epoch 283 | Logic-MLP (loss/acc/sat): 0.627/0.533/0.373(0.376)
# Epoch 284 | Logic-MLP (loss/acc/sat): 0.627/0.533/0.373(0.377)
# Epoch 285 | Logic-MLP (loss/acc/sat): 0.626/0.533/0.374(0.377)
# Epoch 286 | Logic-MLP (loss/acc/sat): 0.626/0.533/0.374(0.378)
# Epoch 287 | Logic-MLP (loss/acc/sat): 0.625/0.534/0.375(0.378)
# Epoch 288 | Logic-MLP (loss/acc/sat): 0.625/0.534/0.375(0.378)
# Epoch 289 | Logic-MLP (loss/acc/sat): 0.625/0.535/0.375(0.379)
# Epoch 290 | Logic-MLP (loss/acc/sat): 0.624/0.535/0.376(0.379)
# Epoch 291 | Logic-MLP (loss/acc/sat): 0.624/0.536/0.376(0.380)
# Epoch 292 | Logic-MLP (loss/acc/sat): 0.624/0.535/0.376(0.380)
# Epoch 293 | Logic-MLP (loss/acc/sat): 0.623/0.536/0.377(0.380)
# Epoch 294 | Logic-MLP (loss/acc/sat): 0.623/0.537/0.377(0.381)
# Epoch 295 | Logic-MLP (loss/acc/sat): 0.622/0.538/0.378(0.381)
# Epoch 296 | Logic-MLP (loss/acc/sat): 0.622/0.538/0.378(0.381)
# Epoch 297 | Logic-MLP (loss/acc/sat): 0.622/0.538/0.378(0.382)
# Epoch 298 | Logic-MLP (loss/acc/sat): 0.621/0.539/0.379(0.382)
# Epoch 299 | Logic-MLP (loss/acc/sat): 0.621/0.539/0.379(0.382)
# Epoch 300 | Logic-MLP (loss/acc/sat): 0.621/0.539/0.379(0.383)
# Epoch 301 | Logic-MLP (loss/acc/sat): 0.620/0.540/0.380(0.383)
# Epoch 302 | Logic-MLP (loss/acc/sat): 0.620/0.540/0.380(0.384)
# Epoch 303 | Logic-MLP (loss/acc/sat): 0.619/0.540/0.381(0.384)
# Epoch 304 | Logic-MLP (loss/acc/sat): 0.619/0.540/0.381(0.384)
# Epoch 305 | Logic-MLP (loss/acc/sat): 0.619/0.540/0.381(0.385)
# Epoch 306 | Logic-MLP (loss/acc/sat): 0.618/0.541/0.382(0.385)
# Epoch 307 | Logic-MLP (loss/acc/sat): 0.618/0.542/0.382(0.385)
# Epoch 308 | Logic-MLP (loss/acc/sat): 0.618/0.542/0.382(0.386)
# Epoch 309 | Logic-MLP (loss/acc/sat): 0.617/0.542/0.383(0.386)
# Epoch 310 | Logic-MLP (loss/acc/sat): 0.617/0.542/0.383(0.386)
# Epoch 311 | Logic-MLP (loss/acc/sat): 0.617/0.543/0.383(0.387)
# Epoch 312 | Logic-MLP (loss/acc/sat): 0.616/0.543/0.384(0.387)
# Epoch 313 | Logic-MLP (loss/acc/sat): 0.616/0.544/0.384(0.387)
# Epoch 314 | Logic-MLP (loss/acc/sat): 0.616/0.544/0.384(0.388)
# Epoch 315 | Logic-MLP (loss/acc/sat): 0.615/0.544/0.385(0.388)
# Epoch 316 | Logic-MLP (loss/acc/sat): 0.615/0.544/0.385(0.388)
# Epoch 317 | Logic-MLP (loss/acc/sat): 0.615/0.544/0.385(0.388)
# Epoch 318 | Logic-MLP (loss/acc/sat): 0.615/0.545/0.385(0.389)
# Epoch 319 | Logic-MLP (loss/acc/sat): 0.614/0.545/0.386(0.389)
# Epoch 320 | Logic-MLP (loss/acc/sat): 0.614/0.544/0.386(0.389)
# Epoch 321 | Logic-MLP (loss/acc/sat): 0.614/0.545/0.386(0.390)
# Epoch 322 | Logic-MLP (loss/acc/sat): 0.613/0.545/0.387(0.390)
# Epoch 323 | Logic-MLP (loss/acc/sat): 0.613/0.545/0.387(0.390)
# Epoch 324 | Logic-MLP (loss/acc/sat): 0.613/0.545/0.387(0.391)
# Epoch 325 | Logic-MLP (loss/acc/sat): 0.612/0.545/0.388(0.391)
# Epoch 326 | Logic-MLP (loss/acc/sat): 0.612/0.546/0.388(0.391)
# Epoch 327 | Logic-MLP (loss/acc/sat): 0.612/0.545/0.388(0.391)
# Epoch 328 | Logic-MLP (loss/acc/sat): 0.612/0.546/0.388(0.392)
# Epoch 329 | Logic-MLP (loss/acc/sat): 0.611/0.545/0.389(0.392)
# Epoch 330 | Logic-MLP (loss/acc/sat): 0.611/0.545/0.389(0.392)
# Epoch 331 | Logic-MLP (loss/acc/sat): 0.611/0.546/0.389(0.393)
# Epoch 332 | Logic-MLP (loss/acc/sat): 0.610/0.546/0.390(0.393)
# Epoch 333 | Logic-MLP (loss/acc/sat): 0.610/0.546/0.390(0.393)
# Epoch 334 | Logic-MLP (loss/acc/sat): 0.610/0.547/0.390(0.393)
# Epoch 335 | Logic-MLP (loss/acc/sat): 0.610/0.548/0.390(0.394)
# Epoch 336 | Logic-MLP (loss/acc/sat): 0.609/0.548/0.391(0.394)
# Epoch 337 | Logic-MLP (loss/acc/sat): 0.609/0.548/0.391(0.394)
# Epoch 338 | Logic-MLP (loss/acc/sat): 0.609/0.548/0.391(0.394)
# Epoch 339 | Logic-MLP (loss/acc/sat): 0.609/0.548/0.391(0.395)
# Epoch 340 | Logic-MLP (loss/acc/sat): 0.608/0.548/0.392(0.395)
# Epoch 341 | Logic-MLP (loss/acc/sat): 0.608/0.549/0.392(0.395)
# Epoch 342 | Logic-MLP (loss/acc/sat): 0.608/0.549/0.392(0.395)
# Epoch 343 | Logic-MLP (loss/acc/sat): 0.607/0.549/0.393(0.396)
# Epoch 344 | Logic-MLP (loss/acc/sat): 0.607/0.549/0.393(0.396)
# Epoch 345 | Logic-MLP (loss/acc/sat): 0.607/0.549/0.393(0.396)
# Epoch 346 | Logic-MLP (loss/acc/sat): 0.607/0.549/0.393(0.396)
# Epoch 347 | Logic-MLP (loss/acc/sat): 0.606/0.549/0.394(0.397)
# Epoch 348 | Logic-MLP (loss/acc/sat): 0.606/0.549/0.394(0.397)
# Epoch 349 | Logic-MLP (loss/acc/sat): 0.606/0.549/0.394(0.397)
# Epoch 350 | Logic-MLP (loss/acc/sat): 0.606/0.549/0.394(0.397)
# Epoch 351 | Logic-MLP (loss/acc/sat): 0.606/0.549/0.394(0.398)
# Epoch 352 | Logic-MLP (loss/acc/sat): 0.605/0.549/0.395(0.398)
# Epoch 353 | Logic-MLP (loss/acc/sat): 0.605/0.549/0.395(0.398)
# Epoch 354 | Logic-MLP (loss/acc/sat): 0.605/0.549/0.395(0.398)
# Epoch 355 | Logic-MLP (loss/acc/sat): 0.605/0.549/0.395(0.399)
# Epoch 356 | Logic-MLP (loss/acc/sat): 0.604/0.550/0.396(0.399)
# Epoch 357 | Logic-MLP (loss/acc/sat): 0.604/0.550/0.396(0.399)
# Epoch 358 | Logic-MLP (loss/acc/sat): 0.604/0.551/0.396(0.399)
# Epoch 359 | Logic-MLP (loss/acc/sat): 0.604/0.551/0.396(0.399)
# Epoch 360 | Logic-MLP (loss/acc/sat): 0.603/0.551/0.397(0.400)
# Epoch 361 | Logic-MLP (loss/acc/sat): 0.603/0.551/0.397(0.400)
# Epoch 362 | Logic-MLP (loss/acc/sat): 0.603/0.551/0.397(0.400)
# Epoch 363 | Logic-MLP (loss/acc/sat): 0.603/0.551/0.397(0.400)
# Epoch 364 | Logic-MLP (loss/acc/sat): 0.603/0.552/0.397(0.401)
# Epoch 365 | Logic-MLP (loss/acc/sat): 0.602/0.552/0.398(0.401)
# Epoch 366 | Logic-MLP (loss/acc/sat): 0.602/0.552/0.398(0.401)
# Epoch 367 | Logic-MLP (loss/acc/sat): 0.602/0.552/0.398(0.401)
# Epoch 368 | Logic-MLP (loss/acc/sat): 0.602/0.552/0.398(0.401)
# Epoch 369 | Logic-MLP (loss/acc/sat): 0.601/0.552/0.399(0.402)
# Epoch 370 | Logic-MLP (loss/acc/sat): 0.601/0.552/0.399(0.402)
# Epoch 371 | Logic-MLP (loss/acc/sat): 0.601/0.552/0.399(0.402)
# Epoch 372 | Logic-MLP (loss/acc/sat): 0.601/0.552/0.399(0.402)
# Epoch 373 | Logic-MLP (loss/acc/sat): 0.601/0.552/0.399(0.402)
# Epoch 374 | Logic-MLP (loss/acc/sat): 0.600/0.552/0.400(0.403)
# Epoch 375 | Logic-MLP (loss/acc/sat): 0.600/0.553/0.400(0.403)
# Epoch 376 | Logic-MLP (loss/acc/sat): 0.600/0.553/0.400(0.403)
# Epoch 377 | Logic-MLP (loss/acc/sat): 0.600/0.553/0.400(0.403)
# Epoch 378 | Logic-MLP (loss/acc/sat): 0.600/0.553/0.400(0.403)
# Epoch 379 | Logic-MLP (loss/acc/sat): 0.599/0.553/0.401(0.404)
# Epoch 380 | Logic-MLP (loss/acc/sat): 0.599/0.553/0.401(0.404)
# Epoch 381 | Logic-MLP (loss/acc/sat): 0.599/0.554/0.401(0.404)
# Epoch 382 | Logic-MLP (loss/acc/sat): 0.599/0.554/0.401(0.404)
# Epoch 383 | Logic-MLP (loss/acc/sat): 0.599/0.554/0.401(0.404)
# Epoch 384 | Logic-MLP (loss/acc/sat): 0.598/0.554/0.402(0.405)
# Epoch 385 | Logic-MLP (loss/acc/sat): 0.598/0.554/0.402(0.405)
# Epoch 386 | Logic-MLP (loss/acc/sat): 0.598/0.554/0.402(0.405)
# Epoch 387 | Logic-MLP (loss/acc/sat): 0.598/0.555/0.402(0.405)
# Epoch 388 | Logic-MLP (loss/acc/sat): 0.598/0.556/0.402(0.405)
# Epoch 389 | Logic-MLP (loss/acc/sat): 0.597/0.556/0.403(0.406)
# Epoch 390 | Logic-MLP (loss/acc/sat): 0.597/0.556/0.403(0.406)
# Epoch 391 | Logic-MLP (loss/acc/sat): 0.597/0.556/0.403(0.406)
# Epoch 392 | Logic-MLP (loss/acc/sat): 0.597/0.556/0.403(0.406)
# Epoch 393 | Logic-MLP (loss/acc/sat): 0.597/0.556/0.403(0.406)
# Epoch 394 | Logic-MLP (loss/acc/sat): 0.596/0.556/0.404(0.406)
# Epoch 395 | Logic-MLP (loss/acc/sat): 0.596/0.557/0.404(0.407)
# Epoch 396 | Logic-MLP (loss/acc/sat): 0.596/0.557/0.404(0.407)
# Epoch 397 | Logic-MLP (loss/acc/sat): 0.596/0.557/0.404(0.407)
# Epoch 398 | Logic-MLP (loss/acc/sat): 0.596/0.557/0.404(0.407)
# Epoch 399 | Logic-MLP (loss/acc/sat): 0.596/0.557/0.404(0.407)
# Epoch 400 | Logic-MLP (loss/acc/sat): 0.595/0.557/0.405(0.408)
# Epoch 401 | Logic-MLP (loss/acc/sat): 0.595/0.557/0.405(0.408)
# Epoch 402 | Logic-MLP (loss/acc/sat): 0.595/0.558/0.405(0.408)
# Epoch 403 | Logic-MLP (loss/acc/sat): 0.595/0.558/0.405(0.408)
# Epoch 404 | Logic-MLP (loss/acc/sat): 0.595/0.558/0.405(0.408)
# Epoch 405 | Logic-MLP (loss/acc/sat): 0.594/0.558/0.406(0.408)
# Epoch 406 | Logic-MLP (loss/acc/sat): 0.594/0.558/0.406(0.409)
# Epoch 407 | Logic-MLP (loss/acc/sat): 0.594/0.558/0.406(0.409)
# Epoch 408 | Logic-MLP (loss/acc/sat): 0.594/0.558/0.406(0.409)
# Epoch 409 | Logic-MLP (loss/acc/sat): 0.594/0.558/0.406(0.409)
# Epoch 410 | Logic-MLP (loss/acc/sat): 0.594/0.558/0.406(0.409)
# Epoch 411 | Logic-MLP (loss/acc/sat): 0.593/0.558/0.407(0.410)
# Epoch 412 | Logic-MLP (loss/acc/sat): 0.593/0.559/0.407(0.410)
# Epoch 413 | Logic-MLP (loss/acc/sat): 0.593/0.559/0.407(0.410)
# Epoch 414 | Logic-MLP (loss/acc/sat): 0.593/0.559/0.407(0.410)
# Epoch 415 | Logic-MLP (loss/acc/sat): 0.593/0.559/0.407(0.410)
# Epoch 416 | Logic-MLP (loss/acc/sat): 0.592/0.560/0.408(0.410)
# Epoch 417 | Logic-MLP (loss/acc/sat): 0.592/0.560/0.408(0.411)
# Epoch 418 | Logic-MLP (loss/acc/sat): 0.592/0.560/0.408(0.411)
# Epoch 419 | Logic-MLP (loss/acc/sat): 0.592/0.560/0.408(0.411)
# Epoch 420 | Logic-MLP (loss/acc/sat): 0.592/0.560/0.408(0.411)
# Epoch 421 | Logic-MLP (loss/acc/sat): 0.592/0.560/0.408(0.411)
# Epoch 422 | Logic-MLP (loss/acc/sat): 0.591/0.560/0.409(0.411)
# Epoch 423 | Logic-MLP (loss/acc/sat): 0.591/0.561/0.409(0.412)
# Epoch 424 | Logic-MLP (loss/acc/sat): 0.591/0.561/0.409(0.412)
# Epoch 425 | Logic-MLP (loss/acc/sat): 0.591/0.561/0.409(0.412)
# Epoch 426 | Logic-MLP (loss/acc/sat): 0.591/0.561/0.409(0.412)
# Epoch 427 | Logic-MLP (loss/acc/sat): 0.591/0.561/0.409(0.412)
# Epoch 428 | Logic-MLP (loss/acc/sat): 0.590/0.561/0.410(0.412)
# Epoch 429 | Logic-MLP (loss/acc/sat): 0.590/0.561/0.410(0.413)
# Epoch 430 | Logic-MLP (loss/acc/sat): 0.590/0.561/0.410(0.413)
# Epoch 431 | Logic-MLP (loss/acc/sat): 0.590/0.561/0.410(0.413)
# Epoch 432 | Logic-MLP (loss/acc/sat): 0.590/0.561/0.410(0.413)
# Epoch 433 | Logic-MLP (loss/acc/sat): 0.589/0.561/0.411(0.413)
# Epoch 434 | Logic-MLP (loss/acc/sat): 0.589/0.561/0.411(0.413)
# Epoch 435 | Logic-MLP (loss/acc/sat): 0.589/0.562/0.411(0.414)
# Epoch 436 | Logic-MLP (loss/acc/sat): 0.589/0.562/0.411(0.414)
# Epoch 437 | Logic-MLP (loss/acc/sat): 0.589/0.562/0.411(0.414)
# Epoch 438 | Logic-MLP (loss/acc/sat): 0.589/0.563/0.411(0.414)
# Epoch 439 | Logic-MLP (loss/acc/sat): 0.588/0.563/0.412(0.414)
# Epoch 440 | Logic-MLP (loss/acc/sat): 0.588/0.563/0.412(0.414)
# Epoch 441 | Logic-MLP (loss/acc/sat): 0.588/0.563/0.412(0.415)
# Epoch 442 | Logic-MLP (loss/acc/sat): 0.588/0.563/0.412(0.415)
# Epoch 443 | Logic-MLP (loss/acc/sat): 0.588/0.563/0.412(0.415)
# Epoch 444 | Logic-MLP (loss/acc/sat): 0.588/0.563/0.412(0.415)
# Epoch 445 | Logic-MLP (loss/acc/sat): 0.587/0.563/0.413(0.415)
# Epoch 446 | Logic-MLP (loss/acc/sat): 0.587/0.563/0.413(0.415)
# Epoch 447 | Logic-MLP (loss/acc/sat): 0.587/0.563/0.413(0.416)
# Epoch 448 | Logic-MLP (loss/acc/sat): 0.587/0.564/0.413(0.416)
# Epoch 449 | Logic-MLP (loss/acc/sat): 0.587/0.564/0.413(0.416)
# Epoch 450 | Logic-MLP (loss/acc/sat): 0.587/0.564/0.413(0.416)
# Epoch 451 | Logic-MLP (loss/acc/sat): 0.586/0.564/0.414(0.416)
# Epoch 452 | Logic-MLP (loss/acc/sat): 0.586/0.565/0.414(0.417)
# Epoch 453 | Logic-MLP (loss/acc/sat): 0.586/0.565/0.414(0.417)
# Epoch 454 | Logic-MLP (loss/acc/sat): 0.586/0.565/0.414(0.417)
# Epoch 455 | Logic-MLP (loss/acc/sat): 0.586/0.565/0.414(0.417)
# Epoch 456 | Logic-MLP (loss/acc/sat): 0.585/0.565/0.415(0.417)
# Epoch 457 | Logic-MLP (loss/acc/sat): 0.585/0.566/0.415(0.417)
# Epoch 458 | Logic-MLP (loss/acc/sat): 0.585/0.566/0.415(0.418)
# Epoch 459 | Logic-MLP (loss/acc/sat): 0.585/0.566/0.415(0.418)
# Epoch 460 | Logic-MLP (loss/acc/sat): 0.585/0.567/0.415(0.418)
# Epoch 461 | Logic-MLP (loss/acc/sat): 0.585/0.567/0.415(0.418)
# Epoch 462 | Logic-MLP (loss/acc/sat): 0.584/0.567/0.416(0.418)
# Epoch 463 | Logic-MLP (loss/acc/sat): 0.584/0.567/0.416(0.418)
# Epoch 464 | Logic-MLP (loss/acc/sat): 0.584/0.567/0.416(0.418)
# Epoch 465 | Logic-MLP (loss/acc/sat): 0.584/0.567/0.416(0.419)
# Epoch 466 | Logic-MLP (loss/acc/sat): 0.584/0.567/0.416(0.419)
# Epoch 467 | Logic-MLP (loss/acc/sat): 0.584/0.568/0.416(0.419)
# Epoch 468 | Logic-MLP (loss/acc/sat): 0.583/0.568/0.417(0.419)
# Epoch 469 | Logic-MLP (loss/acc/sat): 0.583/0.568/0.417(0.419)
# Epoch 470 | Logic-MLP (loss/acc/sat): 0.583/0.568/0.417(0.419)
# Epoch 471 | Logic-MLP (loss/acc/sat): 0.583/0.568/0.417(0.420)
# Epoch 472 | Logic-MLP (loss/acc/sat): 0.583/0.568/0.417(0.420)
# Epoch 473 | Logic-MLP (loss/acc/sat): 0.583/0.568/0.417(0.420)
# Epoch 474 | Logic-MLP (loss/acc/sat): 0.582/0.568/0.418(0.420)
# Epoch 475 | Logic-MLP (loss/acc/sat): 0.582/0.568/0.418(0.420)
# Epoch 476 | Logic-MLP (loss/acc/sat): 0.582/0.569/0.418(0.420)
# Epoch 477 | Logic-MLP (loss/acc/sat): 0.582/0.570/0.418(0.421)
# Epoch 478 | Logic-MLP (loss/acc/sat): 0.582/0.570/0.418(0.421)
# Epoch 479 | Logic-MLP (loss/acc/sat): 0.582/0.570/0.418(0.421)
# Epoch 480 | Logic-MLP (loss/acc/sat): 0.581/0.570/0.419(0.421)
# Epoch 481 | Logic-MLP (loss/acc/sat): 0.581/0.570/0.419(0.421)
# Epoch 482 | Logic-MLP (loss/acc/sat): 0.581/0.570/0.419(0.421)
# Epoch 483 | Logic-MLP (loss/acc/sat): 0.581/0.570/0.419(0.422)
# Epoch 484 | Logic-MLP (loss/acc/sat): 0.581/0.570/0.419(0.422)
# Epoch 485 | Logic-MLP (loss/acc/sat): 0.581/0.570/0.419(0.422)
# Epoch 486 | Logic-MLP (loss/acc/sat): 0.580/0.570/0.420(0.422)
# Epoch 487 | Logic-MLP (loss/acc/sat): 0.580/0.571/0.420(0.422)
# Epoch 488 | Logic-MLP (loss/acc/sat): 0.580/0.571/0.420(0.422)
# Epoch 489 | Logic-MLP (loss/acc/sat): 0.580/0.571/0.420(0.422)
# Epoch 490 | Logic-MLP (loss/acc/sat): 0.580/0.571/0.420(0.423)
# Epoch 491 | Logic-MLP (loss/acc/sat): 0.580/0.572/0.420(0.423)
# Epoch 492 | Logic-MLP (loss/acc/sat): 0.579/0.572/0.421(0.423)
# Epoch 493 | Logic-MLP (loss/acc/sat): 0.579/0.572/0.421(0.423)
# Epoch 494 | Logic-MLP (loss/acc/sat): 0.579/0.572/0.421(0.423)
# Epoch 495 | Logic-MLP (loss/acc/sat): 0.579/0.572/0.421(0.423)
# Epoch 496 | Logic-MLP (loss/acc/sat): 0.579/0.572/0.421(0.424)
# Epoch 497 | Logic-MLP (loss/acc/sat): 0.579/0.572/0.421(0.424)
# Epoch 498 | Logic-MLP (loss/acc/sat): 0.579/0.572/0.421(0.424)
# Epoch 499 | Logic-MLP (loss/acc/sat): 0.578/0.572/0.422(0.424)
# Epoch 500 | Logic-MLP (loss/acc/sat): 0.578/0.572/0.422(0.424)
# Epoch 501 | Logic-MLP (loss/acc/sat): 0.578/0.573/0.422(0.424)
# Epoch 502 | Logic-MLP (loss/acc/sat): 0.578/0.573/0.422(0.424)
# Epoch 503 | Logic-MLP (loss/acc/sat): 0.578/0.573/0.422(0.425)
# Epoch 504 | Logic-MLP (loss/acc/sat): 0.578/0.573/0.422(0.425)
# Epoch 505 | Logic-MLP (loss/acc/sat): 0.577/0.573/0.423(0.425)
# Epoch 506 | Logic-MLP (loss/acc/sat): 0.577/0.573/0.423(0.425)
# Epoch 507 | Logic-MLP (loss/acc/sat): 0.577/0.573/0.423(0.425)
# Epoch 508 | Logic-MLP (loss/acc/sat): 0.577/0.574/0.423(0.425)
# Epoch 509 | Logic-MLP (loss/acc/sat): 0.577/0.574/0.423(0.425)
# Epoch 510 | Logic-MLP (loss/acc/sat): 0.577/0.574/0.423(0.426)
# Epoch 511 | Logic-MLP (loss/acc/sat): 0.577/0.574/0.423(0.426)
# Epoch 512 | Logic-MLP (loss/acc/sat): 0.576/0.574/0.424(0.426)
# Epoch 513 | Logic-MLP (loss/acc/sat): 0.576/0.574/0.424(0.426)
# Epoch 514 | Logic-MLP (loss/acc/sat): 0.576/0.575/0.424(0.426)
# Epoch 515 | Logic-MLP (loss/acc/sat): 0.576/0.575/0.424(0.426)
# Epoch 516 | Logic-MLP (loss/acc/sat): 0.576/0.575/0.424(0.426)
# Epoch 517 | Logic-MLP (loss/acc/sat): 0.576/0.576/0.424(0.427)
# Epoch 518 | Logic-MLP (loss/acc/sat): 0.576/0.576/0.424(0.427)
# Epoch 519 | Logic-MLP (loss/acc/sat): 0.575/0.576/0.425(0.427)
# Epoch 520 | Logic-MLP (loss/acc/sat): 0.575/0.576/0.425(0.427)
# Epoch 521 | Logic-MLP (loss/acc/sat): 0.575/0.576/0.425(0.427)
# Epoch 522 | Logic-MLP (loss/acc/sat): 0.575/0.576/0.425(0.427)
# Epoch 523 | Logic-MLP (loss/acc/sat): 0.575/0.576/0.425(0.427)
# Epoch 524 | Logic-MLP (loss/acc/sat): 0.575/0.576/0.425(0.428)
# Epoch 525 | Logic-MLP (loss/acc/sat): 0.575/0.576/0.425(0.428)
# Epoch 526 | Logic-MLP (loss/acc/sat): 0.574/0.576/0.426(0.428)
# Epoch 527 | Logic-MLP (loss/acc/sat): 0.574/0.577/0.426(0.428)
# Epoch 528 | Logic-MLP (loss/acc/sat): 0.574/0.577/0.426(0.428)
# Epoch 529 | Logic-MLP (loss/acc/sat): 0.574/0.577/0.426(0.428)
# Epoch 530 | Logic-MLP (loss/acc/sat): 0.574/0.577/0.426(0.428)
# Epoch 531 | Logic-MLP (loss/acc/sat): 0.574/0.577/0.426(0.428)
# Epoch 532 | Logic-MLP (loss/acc/sat): 0.574/0.577/0.426(0.429)
# Epoch 533 | Logic-MLP (loss/acc/sat): 0.573/0.577/0.427(0.429)
# Epoch 534 | Logic-MLP (loss/acc/sat): 0.573/0.577/0.427(0.429)
# Epoch 535 | Logic-MLP (loss/acc/sat): 0.573/0.577/0.427(0.429)
# Epoch 536 | Logic-MLP (loss/acc/sat): 0.573/0.577/0.427(0.429)
# Epoch 537 | Logic-MLP (loss/acc/sat): 0.573/0.578/0.427(0.429)
# Epoch 538 | Logic-MLP (loss/acc/sat): 0.573/0.578/0.427(0.429)
# Epoch 539 | Logic-MLP (loss/acc/sat): 0.573/0.578/0.427(0.430)
# Epoch 540 | Logic-MLP (loss/acc/sat): 0.572/0.578/0.428(0.430)
# Epoch 541 | Logic-MLP (loss/acc/sat): 0.572/0.578/0.428(0.430)
# Epoch 542 | Logic-MLP (loss/acc/sat): 0.572/0.578/0.428(0.430)
# Epoch 543 | Logic-MLP (loss/acc/sat): 0.572/0.578/0.428(0.430)
# Epoch 544 | Logic-MLP (loss/acc/sat): 0.572/0.579/0.428(0.430)
# Epoch 545 | Logic-MLP (loss/acc/sat): 0.572/0.579/0.428(0.430)
# Epoch 546 | Logic-MLP (loss/acc/sat): 0.572/0.579/0.428(0.430)
# Epoch 547 | Logic-MLP (loss/acc/sat): 0.571/0.579/0.429(0.431)
# Epoch 548 | Logic-MLP (loss/acc/sat): 0.571/0.579/0.429(0.431)
# Epoch 549 | Logic-MLP (loss/acc/sat): 0.571/0.579/0.429(0.431)
# Epoch 550 | Logic-MLP (loss/acc/sat): 0.571/0.579/0.429(0.431)
# Epoch 551 | Logic-MLP (loss/acc/sat): 0.571/0.579/0.429(0.431)
# Epoch 552 | Logic-MLP (loss/acc/sat): 0.571/0.579/0.429(0.431)
# Epoch 553 | Logic-MLP (loss/acc/sat): 0.571/0.579/0.429(0.431)
# Epoch 554 | Logic-MLP (loss/acc/sat): 0.570/0.580/0.430(0.432)
# Epoch 555 | Logic-MLP (loss/acc/sat): 0.570/0.580/0.430(0.432)
# Epoch 556 | Logic-MLP (loss/acc/sat): 0.570/0.581/0.430(0.432)
# Epoch 557 | Logic-MLP (loss/acc/sat): 0.570/0.581/0.430(0.432)
# Epoch 558 | Logic-MLP (loss/acc/sat): 0.570/0.581/0.430(0.432)
# Epoch 559 | Logic-MLP (loss/acc/sat): 0.570/0.581/0.430(0.432)
# Epoch 560 | Logic-MLP (loss/acc/sat): 0.570/0.582/0.430(0.432)
# Epoch 561 | Logic-MLP (loss/acc/sat): 0.569/0.582/0.431(0.433)
# Epoch 562 | Logic-MLP (loss/acc/sat): 0.569/0.582/0.431(0.433)
# Epoch 563 | Logic-MLP (loss/acc/sat): 0.569/0.582/0.431(0.433)
# Epoch 564 | Logic-MLP (loss/acc/sat): 0.569/0.582/0.431(0.433)
# Epoch 565 | Logic-MLP (loss/acc/sat): 0.569/0.582/0.431(0.433)
# Epoch 566 | Logic-MLP (loss/acc/sat): 0.569/0.583/0.431(0.433)
# Epoch 567 | Logic-MLP (loss/acc/sat): 0.569/0.583/0.431(0.433)
# Epoch 568 | Logic-MLP (loss/acc/sat): 0.568/0.583/0.432(0.433)
# Epoch 569 | Logic-MLP (loss/acc/sat): 0.568/0.583/0.432(0.434)
# Epoch 570 | Logic-MLP (loss/acc/sat): 0.568/0.583/0.432(0.434)
# Epoch 571 | Logic-MLP (loss/acc/sat): 0.568/0.583/0.432(0.434)
# Epoch 572 | Logic-MLP (loss/acc/sat): 0.568/0.583/0.432(0.434)
# Epoch 573 | Logic-MLP (loss/acc/sat): 0.568/0.583/0.432(0.434)
# Epoch 574 | Logic-MLP (loss/acc/sat): 0.567/0.583/0.433(0.434)
# Epoch 575 | Logic-MLP (loss/acc/sat): 0.567/0.584/0.433(0.434)
# Epoch 576 | Logic-MLP (loss/acc/sat): 0.567/0.584/0.433(0.435)
# Epoch 577 | Logic-MLP (loss/acc/sat): 0.567/0.584/0.433(0.435)
# Epoch 578 | Logic-MLP (loss/acc/sat): 0.567/0.584/0.433(0.435)
# Epoch 579 | Logic-MLP (loss/acc/sat): 0.567/0.584/0.433(0.435)
# Epoch 580 | Logic-MLP (loss/acc/sat): 0.567/0.584/0.433(0.435)
# Epoch 581 | Logic-MLP (loss/acc/sat): 0.566/0.585/0.434(0.435)
# Epoch 582 | Logic-MLP (loss/acc/sat): 0.566/0.585/0.434(0.435)
# Epoch 583 | Logic-MLP (loss/acc/sat): 0.566/0.585/0.434(0.436)
# Epoch 584 | Logic-MLP (loss/acc/sat): 0.566/0.585/0.434(0.436)
# Epoch 585 | Logic-MLP (loss/acc/sat): 0.566/0.586/0.434(0.436)
# Epoch 586 | Logic-MLP (loss/acc/sat): 0.566/0.586/0.434(0.436)
# Epoch 587 | Logic-MLP (loss/acc/sat): 0.566/0.586/0.434(0.436)
# Epoch 588 | Logic-MLP (loss/acc/sat): 0.565/0.586/0.435(0.436)
# Epoch 589 | Logic-MLP (loss/acc/sat): 0.565/0.586/0.435(0.436)
# Epoch 590 | Logic-MLP (loss/acc/sat): 0.565/0.586/0.435(0.437)
# Epoch 591 | Logic-MLP (loss/acc/sat): 0.565/0.586/0.435(0.437)
# Epoch 592 | Logic-MLP (loss/acc/sat): 0.565/0.586/0.435(0.437)
# Epoch 593 | Logic-MLP (loss/acc/sat): 0.565/0.587/0.435(0.437)
# Epoch 594 | Logic-MLP (loss/acc/sat): 0.564/0.587/0.436(0.437)
# Epoch 595 | Logic-MLP (loss/acc/sat): 0.564/0.587/0.436(0.437)
# Epoch 596 | Logic-MLP (loss/acc/sat): 0.564/0.587/0.436(0.437)
# Epoch 597 | Logic-MLP (loss/acc/sat): 0.564/0.588/0.436(0.438)
# Epoch 598 | Logic-MLP (loss/acc/sat): 0.564/0.588/0.436(0.438)
# Epoch 599 | Logic-MLP (loss/acc/sat): 0.564/0.589/0.436(0.438)
# Epoch 600 | Logic-MLP (loss/acc/sat): 0.563/0.589/0.437(0.438)
# Epoch 601 | Logic-MLP (loss/acc/sat): 0.563/0.589/0.437(0.438)
# Epoch 602 | Logic-MLP (loss/acc/sat): 0.563/0.589/0.437(0.438)
# Epoch 603 | Logic-MLP (loss/acc/sat): 0.563/0.589/0.437(0.438)
# Epoch 604 | Logic-MLP (loss/acc/sat): 0.563/0.589/0.437(0.439)
# Epoch 605 | Logic-MLP (loss/acc/sat): 0.563/0.589/0.437(0.439)
# Epoch 606 | Logic-MLP (loss/acc/sat): 0.562/0.589/0.438(0.439)
# Epoch 607 | Logic-MLP (loss/acc/sat): 0.562/0.589/0.438(0.439)
# Epoch 608 | Logic-MLP (loss/acc/sat): 0.562/0.589/0.438(0.439)
# Epoch 609 | Logic-MLP (loss/acc/sat): 0.562/0.589/0.438(0.439)
# Epoch 610 | Logic-MLP (loss/acc/sat): 0.562/0.589/0.438(0.440)
# Epoch 611 | Logic-MLP (loss/acc/sat): 0.562/0.589/0.438(0.440)
# Epoch 612 | Logic-MLP (loss/acc/sat): 0.561/0.589/0.439(0.440)
# Epoch 613 | Logic-MLP (loss/acc/sat): 0.561/0.589/0.439(0.440)
# Epoch 614 | Logic-MLP (loss/acc/sat): 0.561/0.590/0.439(0.440)
# Epoch 615 | Logic-MLP (loss/acc/sat): 0.561/0.590/0.439(0.440)
# Epoch 616 | Logic-MLP (loss/acc/sat): 0.561/0.590/0.439(0.440)
# Epoch 617 | Logic-MLP (loss/acc/sat): 0.561/0.590/0.439(0.441)
# Epoch 618 | Logic-MLP (loss/acc/sat): 0.560/0.590/0.440(0.441)
# Epoch 619 | Logic-MLP (loss/acc/sat): 0.560/0.590/0.440(0.441)
# Epoch 620 | Logic-MLP (loss/acc/sat): 0.560/0.591/0.440(0.441)
# Epoch 621 | Logic-MLP (loss/acc/sat): 0.560/0.591/0.440(0.441)
# Epoch 622 | Logic-MLP (loss/acc/sat): 0.560/0.591/0.440(0.442)
# Epoch 623 | Logic-MLP (loss/acc/sat): 0.559/0.592/0.441(0.442)
# Epoch 624 | Logic-MLP (loss/acc/sat): 0.559/0.592/0.441(0.442)
# Epoch 625 | Logic-MLP (loss/acc/sat): 0.559/0.592/0.441(0.442)
# Epoch 626 | Logic-MLP (loss/acc/sat): 0.559/0.593/0.441(0.442)
# Epoch 627 | Logic-MLP (loss/acc/sat): 0.559/0.593/0.441(0.442)
# Epoch 628 | Logic-MLP (loss/acc/sat): 0.558/0.594/0.442(0.443)
# Epoch 629 | Logic-MLP (loss/acc/sat): 0.558/0.594/0.442(0.443)
# Epoch 630 | Logic-MLP (loss/acc/sat): 0.558/0.594/0.442(0.443)
# Epoch 631 | Logic-MLP (loss/acc/sat): 0.558/0.594/0.442(0.443)
# Epoch 632 | Logic-MLP (loss/acc/sat): 0.558/0.595/0.442(0.443)
# Epoch 633 | Logic-MLP (loss/acc/sat): 0.557/0.595/0.443(0.444)
# Epoch 634 | Logic-MLP (loss/acc/sat): 0.557/0.595/0.443(0.444)
# Epoch 635 | Logic-MLP (loss/acc/sat): 0.557/0.596/0.443(0.444)
# Epoch 636 | Logic-MLP (loss/acc/sat): 0.557/0.596/0.443(0.444)
# Epoch 637 | Logic-MLP (loss/acc/sat): 0.556/0.597/0.444(0.444)
# Epoch 638 | Logic-MLP (loss/acc/sat): 0.556/0.597/0.444(0.445)
# Epoch 639 | Logic-MLP (loss/acc/sat): 0.556/0.597/0.444(0.445)
# Epoch 640 | Logic-MLP (loss/acc/sat): 0.556/0.598/0.444(0.445)
# Epoch 641 | Logic-MLP (loss/acc/sat): 0.555/0.598/0.445(0.445)
# Epoch 642 | Logic-MLP (loss/acc/sat): 0.555/0.599/0.445(0.445)
# Epoch 643 | Logic-MLP (loss/acc/sat): 0.555/0.600/0.445(0.446)
# Epoch 644 | Logic-MLP (loss/acc/sat): 0.555/0.600/0.445(0.446)
# Epoch 645 | Logic-MLP (loss/acc/sat): 0.554/0.601/0.446(0.446)
# Epoch 646 | Logic-MLP (loss/acc/sat): 0.554/0.602/0.446(0.446)
# Epoch 647 | Logic-MLP (loss/acc/sat): 0.554/0.603/0.446(0.447)
# Epoch 648 | Logic-MLP (loss/acc/sat): 0.554/0.603/0.446(0.447)
# Epoch 649 | Logic-MLP (loss/acc/sat): 0.553/0.603/0.447(0.447)
# Epoch 650 | Logic-MLP (loss/acc/sat): 0.553/0.604/0.447(0.447)
# Epoch 651 | Logic-MLP (loss/acc/sat): 0.553/0.604/0.447(0.448)
# Epoch 652 | Logic-MLP (loss/acc/sat): 0.553/0.604/0.447(0.448)
# Epoch 653 | Logic-MLP (loss/acc/sat): 0.552/0.604/0.448(0.448)
# Epoch 654 | Logic-MLP (loss/acc/sat): 0.552/0.605/0.448(0.448)
# Epoch 655 | Logic-MLP (loss/acc/sat): 0.552/0.605/0.448(0.449)
# Epoch 656 | Logic-MLP (loss/acc/sat): 0.551/0.605/0.449(0.449)
# Epoch 657 | Logic-MLP (loss/acc/sat): 0.551/0.605/0.449(0.449)
# Epoch 658 | Logic-MLP (loss/acc/sat): 0.551/0.605/0.449(0.449)
# Epoch 659 | Logic-MLP (loss/acc/sat): 0.551/0.605/0.449(0.450)
# Epoch 660 | Logic-MLP (loss/acc/sat): 0.550/0.605/0.450(0.450)
# Epoch 661 | Logic-MLP (loss/acc/sat): 0.550/0.606/0.450(0.450)
# Epoch 662 | Logic-MLP (loss/acc/sat): 0.550/0.606/0.450(0.451)
# Epoch 663 | Logic-MLP (loss/acc/sat): 0.549/0.606/0.451(0.451)
# Epoch 664 | Logic-MLP (loss/acc/sat): 0.549/0.606/0.451(0.451)
# Epoch 665 | Logic-MLP (loss/acc/sat): 0.549/0.606/0.451(0.451)
# Epoch 666 | Logic-MLP (loss/acc/sat): 0.548/0.606/0.452(0.452)
# Epoch 667 | Logic-MLP (loss/acc/sat): 0.548/0.607/0.452(0.452)
# Epoch 668 | Logic-MLP (loss/acc/sat): 0.548/0.607/0.452(0.452)
# Epoch 669 | Logic-MLP (loss/acc/sat): 0.547/0.607/0.453(0.453)
# Epoch 670 | Logic-MLP (loss/acc/sat): 0.547/0.607/0.453(0.453)
# Epoch 671 | Logic-MLP (loss/acc/sat): 0.546/0.608/0.454(0.454)
# Epoch 672 | Logic-MLP (loss/acc/sat): 0.546/0.608/0.454(0.454)
# Epoch 673 | Logic-MLP (loss/acc/sat): 0.546/0.608/0.454(0.455)
# Epoch 674 | Logic-MLP (loss/acc/sat): 0.545/0.608/0.455(0.455)
# Epoch 675 | Logic-MLP (loss/acc/sat): 0.545/0.609/0.455(0.455)
# Epoch 676 | Logic-MLP (loss/acc/sat): 0.544/0.609/0.456(0.456)
# Epoch 677 | Logic-MLP (loss/acc/sat): 0.544/0.609/0.456(0.457)
# Epoch 678 | Logic-MLP (loss/acc/sat): 0.543/0.610/0.457(0.457)
# Epoch 679 | Logic-MLP (loss/acc/sat): 0.542/0.610/0.458(0.458)
# Epoch 680 | Logic-MLP (loss/acc/sat): 0.542/0.610/0.458(0.458)
# Epoch 681 | Logic-MLP (loss/acc/sat): 0.541/0.610/0.459(0.459)
# Epoch 682 | Logic-MLP (loss/acc/sat): 0.540/0.611/0.460(0.460)
# Epoch 683 | Logic-MLP (loss/acc/sat): 0.540/0.611/0.460(0.461)
# Epoch 684 | Logic-MLP (loss/acc/sat): 0.539/0.612/0.461(0.462)
# Epoch 685 | Logic-MLP (loss/acc/sat): 0.538/0.612/0.462(0.463)
# Epoch 686 | Logic-MLP (loss/acc/sat): 0.537/0.612/0.463(0.464)
# Epoch 687 | Logic-MLP (loss/acc/sat): 0.536/0.615/0.464(0.465)
# Epoch 688 | Logic-MLP (loss/acc/sat): 0.535/0.621/0.465(0.466)
# Epoch 689 | Logic-MLP (loss/acc/sat): 0.534/0.635/0.466(0.467)
# Epoch 690 | Logic-MLP (loss/acc/sat): 0.532/0.648/0.468(0.468)
# Epoch 691 | Logic-MLP (loss/acc/sat): 0.531/0.651/0.469(0.469)
# Epoch 692 | Logic-MLP (loss/acc/sat): 0.530/0.656/0.470(0.471)
# Epoch 693 | Logic-MLP (loss/acc/sat): 0.529/0.656/0.471(0.472)
# Epoch 694 | Logic-MLP (loss/acc/sat): 0.528/0.656/0.472(0.473)
# Epoch 695 | Logic-MLP (loss/acc/sat): 0.527/0.656/0.473(0.474)
# Epoch 696 | Logic-MLP (loss/acc/sat): 0.525/0.656/0.475(0.475)
# Epoch 697 | Logic-MLP (loss/acc/sat): 0.525/0.656/0.475(0.476)
# Epoch 698 | Logic-MLP (loss/acc/sat): 0.524/0.656/0.476(0.476)
# Epoch 699 | Logic-MLP (loss/acc/sat): 0.523/0.656/0.477(0.477)
# Epoch 700 | Logic-MLP (loss/acc/sat): 0.522/0.657/0.478(0.478)
# Epoch 701 | Logic-MLP (loss/acc/sat): 0.522/0.657/0.478(0.478)
# Epoch 702 | Logic-MLP (loss/acc/sat): 0.521/0.657/0.479(0.479)
# Epoch 703 | Logic-MLP (loss/acc/sat): 0.521/0.657/0.479(0.479)
# Epoch 704 | Logic-MLP (loss/acc/sat): 0.520/0.658/0.480(0.480)
# Epoch 705 | Logic-MLP (loss/acc/sat): 0.520/0.658/0.480(0.480)
# Epoch 706 | Logic-MLP (loss/acc/sat): 0.519/0.659/0.481(0.480)
# Epoch 707 | Logic-MLP (loss/acc/sat): 0.519/0.659/0.481(0.481)
# Epoch 708 | Logic-MLP (loss/acc/sat): 0.518/0.660/0.482(0.481)
# Epoch 709 | Logic-MLP (loss/acc/sat): 0.518/0.660/0.482(0.482)
# Epoch 710 | Logic-MLP (loss/acc/sat): 0.518/0.661/0.482(0.482)
# Epoch 711 | Logic-MLP (loss/acc/sat): 0.517/0.661/0.483(0.483)
# Epoch 712 | Logic-MLP (loss/acc/sat): 0.517/0.662/0.483(0.483)
# Epoch 713 | Logic-MLP (loss/acc/sat): 0.516/0.663/0.484(0.483)
# Epoch 714 | Logic-MLP (loss/acc/sat): 0.516/0.665/0.484(0.484)
# Epoch 715 | Logic-MLP (loss/acc/sat): 0.515/0.666/0.485(0.484)
# Epoch 716 | Logic-MLP (loss/acc/sat): 0.515/0.666/0.485(0.485)
# Epoch 717 | Logic-MLP (loss/acc/sat): 0.515/0.667/0.485(0.485)
# Epoch 718 | Logic-MLP (loss/acc/sat): 0.514/0.667/0.486(0.485)
# Epoch 719 | Logic-MLP (loss/acc/sat): 0.514/0.668/0.486(0.486)
# Epoch 720 | Logic-MLP (loss/acc/sat): 0.513/0.668/0.487(0.486)
# Epoch 721 | Logic-MLP (loss/acc/sat): 0.513/0.668/0.487(0.486)
# Epoch 722 | Logic-MLP (loss/acc/sat): 0.513/0.668/0.487(0.487)
# Epoch 723 | Logic-MLP (loss/acc/sat): 0.512/0.668/0.488(0.487)
# Epoch 724 | Logic-MLP (loss/acc/sat): 0.512/0.667/0.488(0.487)
# Epoch 725 | Logic-MLP (loss/acc/sat): 0.512/0.665/0.488(0.488)
# Epoch 726 | Logic-MLP (loss/acc/sat): 0.511/0.666/0.489(0.488)
# Epoch 727 | Logic-MLP (loss/acc/sat): 0.511/0.665/0.489(0.488)
# Epoch 728 | Logic-MLP (loss/acc/sat): 0.511/0.664/0.489(0.489)
# Epoch 729 | Logic-MLP (loss/acc/sat): 0.510/0.662/0.490(0.489)
# Epoch 730 | Logic-MLP (loss/acc/sat): 0.510/0.661/0.490(0.489)
# Epoch 731 | Logic-MLP (loss/acc/sat): 0.510/0.661/0.490(0.489)
# Epoch 732 | Logic-MLP (loss/acc/sat): 0.509/0.660/0.491(0.490)
# Epoch 733 | Logic-MLP (loss/acc/sat): 0.509/0.660/0.491(0.490)
# Epoch 734 | Logic-MLP (loss/acc/sat): 0.509/0.659/0.491(0.490)
# Epoch 735 | Logic-MLP (loss/acc/sat): 0.509/0.660/0.491(0.491)
# Epoch 736 | Logic-MLP (loss/acc/sat): 0.508/0.660/0.492(0.491)
# Epoch 737 | Logic-MLP (loss/acc/sat): 0.508/0.660/0.492(0.491)
# Epoch 738 | Logic-MLP (loss/acc/sat): 0.508/0.659/0.492(0.491)
# Epoch 739 | Logic-MLP (loss/acc/sat): 0.507/0.659/0.493(0.492)
# Epoch 740 | Logic-MLP (loss/acc/sat): 0.507/0.660/0.493(0.492)
# Epoch 741 | Logic-MLP (loss/acc/sat): 0.507/0.660/0.493(0.492)
# Epoch 742 | Logic-MLP (loss/acc/sat): 0.507/0.659/0.493(0.492)
# Epoch 743 | Logic-MLP (loss/acc/sat): 0.506/0.659/0.494(0.493)
# Epoch 744 | Logic-MLP (loss/acc/sat): 0.506/0.660/0.494(0.493)
# Epoch 745 | Logic-MLP (loss/acc/sat): 0.506/0.659/0.494(0.493)
# Epoch 746 | Logic-MLP (loss/acc/sat): 0.506/0.660/0.494(0.493)
# Epoch 747 | Logic-MLP (loss/acc/sat): 0.505/0.660/0.495(0.494)
# Epoch 748 | Logic-MLP (loss/acc/sat): 0.505/0.661/0.495(0.494)
# Epoch 749 | Logic-MLP (loss/acc/sat): 0.505/0.661/0.495(0.494)
# Epoch 750 | Logic-MLP (loss/acc/sat): 0.505/0.662/0.495(0.494)
# Epoch 751 | Logic-MLP (loss/acc/sat): 0.504/0.662/0.496(0.495)
# Epoch 752 | Logic-MLP (loss/acc/sat): 0.504/0.662/0.496(0.495)
# Epoch 753 | Logic-MLP (loss/acc/sat): 0.504/0.662/0.496(0.495)
# Epoch 754 | Logic-MLP (loss/acc/sat): 0.504/0.662/0.496(0.495)
# Epoch 755 | Logic-MLP (loss/acc/sat): 0.503/0.662/0.497(0.495)
# Epoch 756 | Logic-MLP (loss/acc/sat): 0.503/0.662/0.497(0.496)
# Epoch 757 | Logic-MLP (loss/acc/sat): 0.503/0.662/0.497(0.496)
# Epoch 758 | Logic-MLP (loss/acc/sat): 0.503/0.662/0.497(0.496)
# Epoch 759 | Logic-MLP (loss/acc/sat): 0.503/0.662/0.497(0.496)
# Epoch 760 | Logic-MLP (loss/acc/sat): 0.502/0.662/0.498(0.497)
# Epoch 761 | Logic-MLP (loss/acc/sat): 0.502/0.662/0.498(0.497)
# Epoch 762 | Logic-MLP (loss/acc/sat): 0.502/0.662/0.498(0.497)
# Epoch 763 | Logic-MLP (loss/acc/sat): 0.502/0.662/0.498(0.497)
# Epoch 764 | Logic-MLP (loss/acc/sat): 0.501/0.663/0.499(0.497)
# Epoch 765 | Logic-MLP (loss/acc/sat): 0.501/0.663/0.499(0.498)
# Epoch 766 | Logic-MLP (loss/acc/sat): 0.501/0.663/0.499(0.498)
# Epoch 767 | Logic-MLP (loss/acc/sat): 0.501/0.663/0.499(0.498)
# Epoch 768 | Logic-MLP (loss/acc/sat): 0.501/0.663/0.499(0.498)
# Epoch 769 | Logic-MLP (loss/acc/sat): 0.500/0.663/0.500(0.498)
# Epoch 770 | Logic-MLP (loss/acc/sat): 0.500/0.663/0.500(0.498)
# Epoch 771 | Logic-MLP (loss/acc/sat): 0.500/0.663/0.500(0.499)
# Epoch 772 | Logic-MLP (loss/acc/sat): 0.500/0.663/0.500(0.499)
# Epoch 773 | Logic-MLP (loss/acc/sat): 0.500/0.663/0.500(0.499)
# Epoch 774 | Logic-MLP (loss/acc/sat): 0.499/0.663/0.501(0.499)
# Epoch 775 | Logic-MLP (loss/acc/sat): 0.499/0.663/0.501(0.499)
# Epoch 776 | Logic-MLP (loss/acc/sat): 0.499/0.663/0.501(0.500)
# Epoch 777 | Logic-MLP (loss/acc/sat): 0.499/0.663/0.501(0.500)
# Epoch 778 | Logic-MLP (loss/acc/sat): 0.499/0.664/0.501(0.500)
# Epoch 779 | Logic-MLP (loss/acc/sat): 0.498/0.664/0.502(0.500)
# Epoch 780 | Logic-MLP (loss/acc/sat): 0.498/0.664/0.502(0.500)
# Epoch 781 | Logic-MLP (loss/acc/sat): 0.498/0.664/0.502(0.500)
# Epoch 782 | Logic-MLP (loss/acc/sat): 0.498/0.664/0.502(0.501)
# Epoch 783 | Logic-MLP (loss/acc/sat): 0.498/0.664/0.502(0.501)
# Epoch 784 | Logic-MLP (loss/acc/sat): 0.498/0.665/0.502(0.501)
# Epoch 785 | Logic-MLP (loss/acc/sat): 0.497/0.664/0.503(0.501)
# Epoch 786 | Logic-MLP (loss/acc/sat): 0.497/0.664/0.503(0.501)
# Epoch 787 | Logic-MLP (loss/acc/sat): 0.497/0.664/0.503(0.501)
# Epoch 788 | Logic-MLP (loss/acc/sat): 0.497/0.664/0.503(0.502)
# Epoch 789 | Logic-MLP (loss/acc/sat): 0.497/0.664/0.503(0.502)
# Epoch 790 | Logic-MLP (loss/acc/sat): 0.496/0.664/0.504(0.502)
# Epoch 791 | Logic-MLP (loss/acc/sat): 0.496/0.664/0.504(0.502)
# Epoch 792 | Logic-MLP (loss/acc/sat): 0.496/0.664/0.504(0.502)
# Epoch 793 | Logic-MLP (loss/acc/sat): 0.496/0.664/0.504(0.502)
# Epoch 794 | Logic-MLP (loss/acc/sat): 0.496/0.664/0.504(0.503)
# Epoch 795 | Logic-MLP (loss/acc/sat): 0.496/0.664/0.504(0.503)
# Epoch 796 | Logic-MLP (loss/acc/sat): 0.495/0.664/0.505(0.503)
# Epoch 797 | Logic-MLP (loss/acc/sat): 0.495/0.664/0.505(0.503)
# Epoch 798 | Logic-MLP (loss/acc/sat): 0.495/0.664/0.505(0.503)
# Epoch 799 | Logic-MLP (loss/acc/sat): 0.495/0.664/0.505(0.503)
# Epoch 800 | Logic-MLP (loss/acc/sat): 0.495/0.665/0.505(0.503)
# Training finished.
# Model saved to /home/zyang44/Github/baseline_cicIOT/P1_structurelevel/efficiency/model_weights/logic_mlp.pt

# %%
def load_model_state(infer_model, model_save_folder, model_name):
    """
    Load the model from disk.
    """
    checkpoint = torch.load(os.path.join(model_save_folder, model_name), 
                            map_location=device)
    infer_model.load_state_dict(checkpoint)
    infer_model.eval()
    return infer_model

# Load the model
logicmlp_infer = MLP(layer_sizes=(18, 10, 6)).to(device)
logicmlp_infer = load_model_state(logicmlp_infer, model_state_folder, 'logic_mlp.pt')
# Test the model
with torch.no_grad():
    for data, labels in test_loader:
        logits = logicmlp_infer(data)
        preds = torch.argmax(logits, dim=1)
        print(f"Predictions: {preds}, Labels: {labels}")
        
        logicmlp_infer_acc = compute_accuracy(test_loader, logicmlp_infer)
        print(f"Test accuracy of the loaded model: {logicmlp_infer_acc.item()}")
        break
# Out:
# Predictions: tensor([2, 2, 1,  ..., 2, 4, 2]), Labels: tensor([2, 0, 0,  ..., 2, 4, 2])
# Test accuracy of the loaded model: 0.6647471189498901
# /tmp/ipykernel_1302988/1958631697.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(os.path.join(model_save_folder, model_name),

# %% [markdown]
# **LogiKNet**

# %%
def compute_sat_levels(loader, P):
	sat_level  = 0
	for data, labels in loader:
		x = ltn.Variable("x", data)
		x_MQTT_DDoS_Connect_Flood = ltn.Variable("x_MQTT_DDoS_Connect_Flood", data[labels == 0])
		x_MQTT_DDoS_Publish_Flood = ltn.Variable("x_MQTT_DDoS_Publish_Flood", data[labels == 1])
		x_MQTT_DoS_Connect_Flood = ltn.Variable("x_MQTT_DoS_Connect_Flood", data[labels == 2])
		x_MQTT_DoS_Publish_Flood = ltn.Variable("x_MQTT_DoS_Publish_Flood", data[labels == 3])
		x_MQTT_Malformed_Data = ltn.Variable("x_MQTT_Malformed_Data", data[labels == 4])
		x_Benign = ltn.Variable("x_Benign", data[labels == 5])

		sat_level = SatAgg(
			Forall(x_MQTT_DDoS_Connect_Flood, P(x_MQTT_DDoS_Connect_Flood, l_MQTT_DDoS_Connect_Flood)),
			Forall(x_MQTT_DDoS_Publish_Flood, P(x_MQTT_DDoS_Publish_Flood, l_MQTT_DDoS_Publish_Flood)),
			Forall(x_MQTT_DoS_Connect_Flood, P(x_MQTT_DoS_Connect_Flood, l_MQTT_DoS_Connect_Flood)),
			Forall(x_MQTT_DoS_Publish_Flood, P(x_MQTT_DoS_Publish_Flood, l_MQTT_DoS_Publish_Flood)),
			Forall(x_MQTT_Malformed_Data, P(x_MQTT_Malformed_Data, l_MQTT_Malformed_Data)),
			Forall(x_Benign, P(x_Benign, l_Benign))
		)
	return sat_level
    
# Define myKAN predicate
kan = KAN(width=[18, 10, 6], grid=5, k=3, seed=42, device=device)
P_kan = ltn.Predicate(LogitsToPredicate(MultiKANModel(kan)))

optimizer_kan = torch.optim.Adam(P_kan.parameters(), lr=0.001)

for epoch in range(401):
	optimizer_kan.zero_grad()
	sat_kan = compute_sat_levels(train_loader, P_kan)
	loss = 1. - sat_kan
	loss.backward()
	optimizer_kan.step()
	train_loss_kan = loss.item()

	# Test the KAN
	test_acc_kan = compute_accuracy(test_loader, kan)
	test_sat_kan = compute_sat_levels(test_loader, P_kan)

	print(f"Epoch {epoch} | KAN (loss/acc/sat): {train_loss_kan:.3f}/{test_acc_kan:.3f}/{sat_kan:.3f}({test_sat_kan:.3f})")

print("Training finished.")

# save the models as .pt files
save_model(kan, model_state_folder, 'logiKAN.pt')
# Out:
# checkpoint directory created: ./model
# saving model version 0.0
# Epoch 0 | KAN (loss/acc/sat): 0.834/0.274/0.166(0.167)
# Epoch 1 | KAN (loss/acc/sat): 0.833/0.285/0.167(0.167)
# Epoch 2 | KAN (loss/acc/sat): 0.833/0.295/0.167(0.168)
# Epoch 3 | KAN (loss/acc/sat): 0.832/0.308/0.168(0.169)
# Epoch 4 | KAN (loss/acc/sat): 0.831/0.317/0.169(0.170)
# Epoch 5 | KAN (loss/acc/sat): 0.831/0.326/0.169(0.170)
# Epoch 6 | KAN (loss/acc/sat): 0.830/0.337/0.170(0.171)
# Epoch 7 | KAN (loss/acc/sat): 0.829/0.346/0.171(0.172)
# Epoch 8 | KAN (loss/acc/sat): 0.829/0.357/0.171(0.172)
# Epoch 9 | KAN (loss/acc/sat): 0.828/0.365/0.172(0.173)
# Epoch 10 | KAN (loss/acc/sat): 0.827/0.371/0.173(0.174)
# Epoch 11 | KAN (loss/acc/sat): 0.826/0.386/0.174(0.175)
# Epoch 12 | KAN (loss/acc/sat): 0.826/0.396/0.174(0.175)
# Epoch 13 | KAN (loss/acc/sat): 0.825/0.408/0.175(0.176)
# Epoch 14 | KAN (loss/acc/sat): 0.824/0.419/0.176(0.177)
# Epoch 15 | KAN (loss/acc/sat): 0.824/0.429/0.176(0.178)
# Epoch 16 | KAN (loss/acc/sat): 0.823/0.438/0.177(0.178)
# Epoch 17 | KAN (loss/acc/sat): 0.822/0.448/0.178(0.179)
# Epoch 18 | KAN (loss/acc/sat): 0.821/0.453/0.179(0.180)
# Epoch 19 | KAN (loss/acc/sat): 0.821/0.456/0.179(0.181)
# Epoch 20 | KAN (loss/acc/sat): 0.820/0.460/0.180(0.182)
# Epoch 21 | KAN (loss/acc/sat): 0.819/0.464/0.181(0.182)
# Epoch 22 | KAN (loss/acc/sat): 0.818/0.472/0.182(0.183)
# Epoch 23 | KAN (loss/acc/sat): 0.817/0.478/0.183(0.184)
# Epoch 24 | KAN (loss/acc/sat): 0.816/0.483/0.184(0.185)
# Epoch 25 | KAN (loss/acc/sat): 0.816/0.486/0.184(0.186)
# Epoch 26 | KAN (loss/acc/sat): 0.815/0.488/0.185(0.187)
# Epoch 27 | KAN (loss/acc/sat): 0.814/0.490/0.186(0.188)
# Epoch 28 | KAN (loss/acc/sat): 0.813/0.493/0.187(0.189)
# Epoch 29 | KAN (loss/acc/sat): 0.812/0.494/0.188(0.190)
# Epoch 30 | KAN (loss/acc/sat): 0.811/0.494/0.189(0.191)
# Epoch 31 | KAN (loss/acc/sat): 0.810/0.494/0.190(0.192)
# Epoch 32 | KAN (loss/acc/sat): 0.809/0.494/0.191(0.193)
# Epoch 33 | KAN (loss/acc/sat): 0.808/0.495/0.192(0.194)
# Epoch 34 | KAN (loss/acc/sat): 0.807/0.496/0.193(0.195)
# Epoch 35 | KAN (loss/acc/sat): 0.806/0.497/0.194(0.196)
# Epoch 36 | KAN (loss/acc/sat): 0.805/0.497/0.195(0.197)
# Epoch 37 | KAN (loss/acc/sat): 0.804/0.497/0.196(0.198)
# Epoch 38 | KAN (loss/acc/sat): 0.803/0.497/0.197(0.199)
# Epoch 39 | KAN (loss/acc/sat): 0.802/0.498/0.198(0.200)
# Epoch 40 | KAN (loss/acc/sat): 0.801/0.497/0.199(0.201)
# Epoch 41 | KAN (loss/acc/sat): 0.800/0.498/0.200(0.202)
# Epoch 42 | KAN (loss/acc/sat): 0.799/0.497/0.201(0.203)
# Epoch 43 | KAN (loss/acc/sat): 0.798/0.497/0.202(0.204)
# Epoch 44 | KAN (loss/acc/sat): 0.797/0.498/0.203(0.206)
# Epoch 45 | KAN (loss/acc/sat): 0.796/0.498/0.204(0.207)
# Epoch 46 | KAN (loss/acc/sat): 0.794/0.498/0.206(0.208)
# Epoch 47 | KAN (loss/acc/sat): 0.793/0.499/0.207(0.209)
# Epoch 48 | KAN (loss/acc/sat): 0.792/0.498/0.208(0.210)
# Epoch 49 | KAN (loss/acc/sat): 0.791/0.498/0.209(0.212)
# Epoch 50 | KAN (loss/acc/sat): 0.790/0.499/0.210(0.213)
# Epoch 51 | KAN (loss/acc/sat): 0.788/0.499/0.212(0.214)
# Epoch 52 | KAN (loss/acc/sat): 0.787/0.499/0.213(0.215)
# Epoch 53 | KAN (loss/acc/sat): 0.786/0.499/0.214(0.217)
# Epoch 54 | KAN (loss/acc/sat): 0.785/0.499/0.215(0.218)
# Epoch 55 | KAN (loss/acc/sat): 0.783/0.499/0.217(0.219)
# Epoch 56 | KAN (loss/acc/sat): 0.782/0.501/0.218(0.221)
# Epoch 57 | KAN (loss/acc/sat): 0.781/0.502/0.219(0.222)
# Epoch 58 | KAN (loss/acc/sat): 0.780/0.503/0.220(0.223)
# Epoch 59 | KAN (loss/acc/sat): 0.778/0.503/0.222(0.225)
# Epoch 60 | KAN (loss/acc/sat): 0.777/0.505/0.223(0.226)
# Epoch 61 | KAN (loss/acc/sat): 0.776/0.507/0.224(0.228)
# Epoch 62 | KAN (loss/acc/sat): 0.774/0.507/0.226(0.229)
# Epoch 63 | KAN (loss/acc/sat): 0.773/0.509/0.227(0.230)
# Epoch 64 | KAN (loss/acc/sat): 0.771/0.508/0.229(0.232)
# Epoch 65 | KAN (loss/acc/sat): 0.770/0.508/0.230(0.233)
# Epoch 66 | KAN (loss/acc/sat): 0.769/0.509/0.231(0.235)
# Epoch 67 | KAN (loss/acc/sat): 0.767/0.509/0.233(0.236)
# Epoch 68 | KAN (loss/acc/sat): 0.766/0.509/0.234(0.238)
# Epoch 69 | KAN (loss/acc/sat): 0.764/0.509/0.236(0.239)
# Epoch 70 | KAN (loss/acc/sat): 0.763/0.510/0.237(0.241)
# Epoch 71 | KAN (loss/acc/sat): 0.761/0.511/0.239(0.242)
# Epoch 72 | KAN (loss/acc/sat): 0.760/0.512/0.240(0.244)
# Epoch 73 | KAN (loss/acc/sat): 0.758/0.513/0.242(0.245)
# Epoch 74 | KAN (loss/acc/sat): 0.757/0.513/0.243(0.247)
# Epoch 75 | KAN (loss/acc/sat): 0.755/0.512/0.245(0.249)
# Epoch 76 | KAN (loss/acc/sat): 0.753/0.511/0.247(0.250)
# Epoch 77 | KAN (loss/acc/sat): 0.752/0.511/0.248(0.252)
# Epoch 78 | KAN (loss/acc/sat): 0.750/0.512/0.250(0.254)
# Epoch 79 | KAN (loss/acc/sat): 0.748/0.512/0.252(0.255)
# Epoch 80 | KAN (loss/acc/sat): 0.747/0.512/0.253(0.257)
# Epoch 81 | KAN (loss/acc/sat): 0.745/0.512/0.255(0.259)
# Epoch 82 | KAN (loss/acc/sat): 0.743/0.512/0.257(0.261)
# Epoch 83 | KAN (loss/acc/sat): 0.742/0.513/0.258(0.262)
# Epoch 84 | KAN (loss/acc/sat): 0.740/0.512/0.260(0.264)
# Epoch 85 | KAN (loss/acc/sat): 0.738/0.514/0.262(0.266)
# Epoch 86 | KAN (loss/acc/sat): 0.736/0.514/0.264(0.268)
# Epoch 87 | KAN (loss/acc/sat): 0.735/0.514/0.265(0.270)
# Epoch 88 | KAN (loss/acc/sat): 0.733/0.513/0.267(0.271)
# Epoch 89 | KAN (loss/acc/sat): 0.731/0.513/0.269(0.273)
# Epoch 90 | KAN (loss/acc/sat): 0.729/0.514/0.271(0.275)
# Epoch 91 | KAN (loss/acc/sat): 0.727/0.514/0.273(0.277)
# Epoch 92 | KAN (loss/acc/sat): 0.726/0.515/0.274(0.279)
# Epoch 93 | KAN (loss/acc/sat): 0.724/0.515/0.276(0.281)
# Epoch 94 | KAN (loss/acc/sat): 0.722/0.515/0.278(0.283)
# Epoch 95 | KAN (loss/acc/sat): 0.720/0.516/0.280(0.284)
# Epoch 96 | KAN (loss/acc/sat): 0.718/0.516/0.282(0.286)
# Epoch 97 | KAN (loss/acc/sat): 0.716/0.516/0.284(0.288)
# Epoch 98 | KAN (loss/acc/sat): 0.714/0.516/0.286(0.290)
# Epoch 99 | KAN (loss/acc/sat): 0.712/0.516/0.288(0.292)
# Epoch 100 | KAN (loss/acc/sat): 0.711/0.517/0.289(0.294)
# Epoch 101 | KAN (loss/acc/sat): 0.709/0.516/0.291(0.296)
# Epoch 102 | KAN (loss/acc/sat): 0.707/0.517/0.293(0.298)
# Epoch 103 | KAN (loss/acc/sat): 0.705/0.517/0.295(0.300)
# Epoch 104 | KAN (loss/acc/sat): 0.703/0.519/0.297(0.302)
# Epoch 105 | KAN (loss/acc/sat): 0.701/0.520/0.299(0.304)
# Epoch 106 | KAN (loss/acc/sat): 0.699/0.520/0.301(0.305)
# Epoch 107 | KAN (loss/acc/sat): 0.697/0.521/0.303(0.307)
# Epoch 108 | KAN (loss/acc/sat): 0.696/0.522/0.304(0.309)
# Epoch 109 | KAN (loss/acc/sat): 0.694/0.522/0.306(0.311)
# Epoch 110 | KAN (loss/acc/sat): 0.692/0.523/0.308(0.313)
# Epoch 111 | KAN (loss/acc/sat): 0.690/0.522/0.310(0.315)
# Epoch 112 | KAN (loss/acc/sat): 0.688/0.523/0.312(0.317)
# Epoch 113 | KAN (loss/acc/sat): 0.686/0.525/0.314(0.319)
# Epoch 114 | KAN (loss/acc/sat): 0.684/0.525/0.316(0.320)
# Epoch 115 | KAN (loss/acc/sat): 0.683/0.526/0.317(0.322)
# Epoch 116 | KAN (loss/acc/sat): 0.681/0.527/0.319(0.324)
# Epoch 117 | KAN (loss/acc/sat): 0.679/0.528/0.321(0.326)
# Epoch 118 | KAN (loss/acc/sat): 0.677/0.528/0.323(0.328)
# Epoch 119 | KAN (loss/acc/sat): 0.675/0.529/0.325(0.329)
# Epoch 120 | KAN (loss/acc/sat): 0.674/0.530/0.326(0.331)
# Epoch 121 | KAN (loss/acc/sat): 0.672/0.530/0.328(0.333)
# Epoch 122 | KAN (loss/acc/sat): 0.670/0.530/0.330(0.335)
# Epoch 123 | KAN (loss/acc/sat): 0.668/0.531/0.332(0.337)
# Epoch 124 | KAN (loss/acc/sat): 0.667/0.532/0.333(0.338)
# Epoch 125 | KAN (loss/acc/sat): 0.665/0.534/0.335(0.340)
# Epoch 126 | KAN (loss/acc/sat): 0.663/0.535/0.337(0.342)
# Epoch 127 | KAN (loss/acc/sat): 0.661/0.536/0.339(0.344)
# Epoch 128 | KAN (loss/acc/sat): 0.660/0.537/0.340(0.345)
# Epoch 129 | KAN (loss/acc/sat): 0.658/0.537/0.342(0.347)
# Epoch 130 | KAN (loss/acc/sat): 0.656/0.539/0.344(0.349)
# Epoch 131 | KAN (loss/acc/sat): 0.654/0.540/0.346(0.350)
# Epoch 132 | KAN (loss/acc/sat): 0.653/0.540/0.347(0.352)
# Epoch 133 | KAN (loss/acc/sat): 0.651/0.542/0.349(0.354)
# Epoch 134 | KAN (loss/acc/sat): 0.649/0.543/0.351(0.355)
# Epoch 135 | KAN (loss/acc/sat): 0.648/0.544/0.352(0.357)
# Epoch 136 | KAN (loss/acc/sat): 0.646/0.544/0.354(0.359)
# Epoch 137 | KAN (loss/acc/sat): 0.644/0.545/0.356(0.360)
# Epoch 138 | KAN (loss/acc/sat): 0.643/0.546/0.357(0.362)
# Epoch 139 | KAN (loss/acc/sat): 0.641/0.547/0.359(0.364)
# Epoch 140 | KAN (loss/acc/sat): 0.639/0.548/0.361(0.365)
# Epoch 141 | KAN (loss/acc/sat): 0.638/0.549/0.362(0.367)
# Epoch 142 | KAN (loss/acc/sat): 0.636/0.550/0.364(0.369)
# Epoch 143 | KAN (loss/acc/sat): 0.634/0.551/0.366(0.370)
# Epoch 144 | KAN (loss/acc/sat): 0.633/0.551/0.367(0.372)
# Epoch 145 | KAN (loss/acc/sat): 0.631/0.553/0.369(0.374)
# Epoch 146 | KAN (loss/acc/sat): 0.629/0.554/0.371(0.375)
# Epoch 147 | KAN (loss/acc/sat): 0.628/0.555/0.372(0.377)
# Epoch 148 | KAN (loss/acc/sat): 0.626/0.556/0.374(0.378)
# Epoch 149 | KAN (loss/acc/sat): 0.624/0.556/0.376(0.380)
# Epoch 150 | KAN (loss/acc/sat): 0.623/0.557/0.377(0.382)
# Epoch 151 | KAN (loss/acc/sat): 0.621/0.558/0.379(0.383)
# Epoch 152 | KAN (loss/acc/sat): 0.619/0.559/0.381(0.385)
# Epoch 153 | KAN (loss/acc/sat): 0.618/0.559/0.382(0.387)
# Epoch 154 | KAN (loss/acc/sat): 0.616/0.561/0.384(0.388)
# Epoch 155 | KAN (loss/acc/sat): 0.614/0.564/0.386(0.390)
# Epoch 156 | KAN (loss/acc/sat): 0.613/0.567/0.387(0.392)
# Epoch 157 | KAN (loss/acc/sat): 0.611/0.570/0.389(0.393)
# Epoch 158 | KAN (loss/acc/sat): 0.609/0.570/0.391(0.395)
# Epoch 159 | KAN (loss/acc/sat): 0.608/0.574/0.392(0.397)
# Epoch 160 | KAN (loss/acc/sat): 0.606/0.577/0.394(0.398)
# Epoch 161 | KAN (loss/acc/sat): 0.604/0.580/0.396(0.400)
# Epoch 162 | KAN (loss/acc/sat): 0.603/0.582/0.397(0.402)
# Epoch 163 | KAN (loss/acc/sat): 0.601/0.586/0.399(0.403)
# Epoch 164 | KAN (loss/acc/sat): 0.599/0.592/0.401(0.405)
# Epoch 165 | KAN (loss/acc/sat): 0.597/0.596/0.403(0.407)
# Epoch 166 | KAN (loss/acc/sat): 0.596/0.600/0.404(0.408)
# Epoch 167 | KAN (loss/acc/sat): 0.594/0.604/0.406(0.410)
# Epoch 168 | KAN (loss/acc/sat): 0.592/0.608/0.408(0.412)
# Epoch 169 | KAN (loss/acc/sat): 0.591/0.610/0.409(0.413)
# Epoch 170 | KAN (loss/acc/sat): 0.589/0.616/0.411(0.415)
# Epoch 171 | KAN (loss/acc/sat): 0.587/0.620/0.413(0.417)
# Epoch 172 | KAN (loss/acc/sat): 0.585/0.625/0.415(0.418)
# Epoch 173 | KAN (loss/acc/sat): 0.584/0.630/0.416(0.420)
# Epoch 174 | KAN (loss/acc/sat): 0.582/0.632/0.418(0.422)
# Epoch 175 | KAN (loss/acc/sat): 0.580/0.634/0.420(0.423)
# Epoch 176 | KAN (loss/acc/sat): 0.578/0.635/0.422(0.425)
# Epoch 177 | KAN (loss/acc/sat): 0.577/0.637/0.423(0.427)
# Epoch 178 | KAN (loss/acc/sat): 0.575/0.640/0.425(0.428)
# Epoch 179 | KAN (loss/acc/sat): 0.573/0.643/0.427(0.430)
# Epoch 180 | KAN (loss/acc/sat): 0.572/0.644/0.428(0.432)
# Epoch 181 | KAN (loss/acc/sat): 0.570/0.647/0.430(0.433)
# Epoch 182 | KAN (loss/acc/sat): 0.568/0.646/0.432(0.435)
# Epoch 183 | KAN (loss/acc/sat): 0.566/0.648/0.434(0.437)
# Epoch 184 | KAN (loss/acc/sat): 0.565/0.647/0.435(0.438)
# Epoch 185 | KAN (loss/acc/sat): 0.563/0.648/0.437(0.440)
# Epoch 186 | KAN (loss/acc/sat): 0.561/0.649/0.439(0.442)
# Epoch 187 | KAN (loss/acc/sat): 0.560/0.649/0.440(0.443)
# Epoch 188 | KAN (loss/acc/sat): 0.558/0.652/0.442(0.445)
# Epoch 189 | KAN (loss/acc/sat): 0.557/0.653/0.443(0.446)
# Epoch 190 | KAN (loss/acc/sat): 0.555/0.653/0.445(0.448)
# Epoch 191 | KAN (loss/acc/sat): 0.553/0.654/0.447(0.449)
# Epoch 192 | KAN (loss/acc/sat): 0.552/0.654/0.448(0.451)
# Epoch 193 | KAN (loss/acc/sat): 0.550/0.654/0.450(0.452)
# Epoch 194 | KAN (loss/acc/sat): 0.549/0.655/0.451(0.454)
# Epoch 195 | KAN (loss/acc/sat): 0.547/0.655/0.453(0.455)
# Epoch 196 | KAN (loss/acc/sat): 0.546/0.655/0.454(0.457)
# Epoch 197 | KAN (loss/acc/sat): 0.544/0.656/0.456(0.458)
# Epoch 198 | KAN (loss/acc/sat): 0.543/0.657/0.457(0.460)
# Epoch 199 | KAN (loss/acc/sat): 0.541/0.658/0.459(0.461)
# Epoch 200 | KAN (loss/acc/sat): 0.540/0.658/0.460(0.463)
# Epoch 201 | KAN (loss/acc/sat): 0.538/0.659/0.462(0.464)
# Epoch 202 | KAN (loss/acc/sat): 0.537/0.659/0.463(0.465)
# Epoch 203 | KAN (loss/acc/sat): 0.536/0.659/0.464(0.467)
# Epoch 204 | KAN (loss/acc/sat): 0.534/0.660/0.466(0.468)
# Epoch 205 | KAN (loss/acc/sat): 0.533/0.660/0.467(0.469)
# Epoch 206 | KAN (loss/acc/sat): 0.532/0.660/0.468(0.471)
# Epoch 207 | KAN (loss/acc/sat): 0.530/0.662/0.470(0.472)
# Epoch 208 | KAN (loss/acc/sat): 0.529/0.663/0.471(0.473)
# Epoch 209 | KAN (loss/acc/sat): 0.528/0.663/0.472(0.475)
# Epoch 210 | KAN (loss/acc/sat): 0.526/0.663/0.474(0.476)
# Epoch 211 | KAN (loss/acc/sat): 0.525/0.663/0.475(0.477)
# Epoch 212 | KAN (loss/acc/sat): 0.524/0.663/0.476(0.478)
# Epoch 213 | KAN (loss/acc/sat): 0.523/0.663/0.477(0.479)
# Epoch 214 | KAN (loss/acc/sat): 0.522/0.665/0.478(0.480)
# Epoch 215 | KAN (loss/acc/sat): 0.520/0.665/0.480(0.482)
# Epoch 216 | KAN (loss/acc/sat): 0.519/0.665/0.481(0.483)
# Epoch 217 | KAN (loss/acc/sat): 0.518/0.666/0.482(0.484)
# Epoch 218 | KAN (loss/acc/sat): 0.517/0.667/0.483(0.485)
# Epoch 219 | KAN (loss/acc/sat): 0.516/0.667/0.484(0.486)
# Epoch 220 | KAN (loss/acc/sat): 0.515/0.667/0.485(0.487)
# Epoch 221 | KAN (loss/acc/sat): 0.514/0.667/0.486(0.488)
# Epoch 222 | KAN (loss/acc/sat): 0.513/0.667/0.487(0.489)
# Epoch 223 | KAN (loss/acc/sat): 0.512/0.668/0.488(0.490)
# Epoch 224 | KAN (loss/acc/sat): 0.511/0.669/0.489(0.491)
# Epoch 225 | KAN (loss/acc/sat): 0.510/0.669/0.490(0.492)
# Epoch 226 | KAN (loss/acc/sat): 0.509/0.669/0.491(0.493)
# Epoch 227 | KAN (loss/acc/sat): 0.508/0.670/0.492(0.494)
# Epoch 228 | KAN (loss/acc/sat): 0.507/0.671/0.493(0.495)
# Epoch 229 | KAN (loss/acc/sat): 0.506/0.671/0.494(0.496)
# Epoch 230 | KAN (loss/acc/sat): 0.505/0.671/0.495(0.497)
# Epoch 231 | KAN (loss/acc/sat): 0.504/0.671/0.496(0.498)
# Epoch 232 | KAN (loss/acc/sat): 0.503/0.671/0.497(0.499)
# Epoch 233 | KAN (loss/acc/sat): 0.502/0.672/0.498(0.499)
# Epoch 234 | KAN (loss/acc/sat): 0.501/0.672/0.499(0.500)
# Epoch 235 | KAN (loss/acc/sat): 0.500/0.673/0.500(0.501)
# Epoch 236 | KAN (loss/acc/sat): 0.499/0.673/0.501(0.502)
# Epoch 237 | KAN (loss/acc/sat): 0.498/0.674/0.502(0.503)
# Epoch 238 | KAN (loss/acc/sat): 0.498/0.674/0.502(0.504)
# Epoch 239 | KAN (loss/acc/sat): 0.497/0.675/0.503(0.504)
# Epoch 240 | KAN (loss/acc/sat): 0.496/0.676/0.504(0.505)
# Epoch 241 | KAN (loss/acc/sat): 0.495/0.676/0.505(0.506)
# Epoch 242 | KAN (loss/acc/sat): 0.494/0.676/0.506(0.507)
# Epoch 243 | KAN (loss/acc/sat): 0.494/0.676/0.506(0.507)
# Epoch 244 | KAN (loss/acc/sat): 0.493/0.676/0.507(0.508)
# Epoch 245 | KAN (loss/acc/sat): 0.492/0.676/0.508(0.509)
# Epoch 246 | KAN (loss/acc/sat): 0.491/0.676/0.509(0.510)
# Epoch 247 | KAN (loss/acc/sat): 0.491/0.676/0.509(0.510)
# Epoch 248 | KAN (loss/acc/sat): 0.490/0.676/0.510(0.511)
# Epoch 249 | KAN (loss/acc/sat): 0.489/0.676/0.511(0.512)
# Epoch 250 | KAN (loss/acc/sat): 0.489/0.676/0.511(0.512)
# Epoch 251 | KAN (loss/acc/sat): 0.488/0.676/0.512(0.513)
# Epoch 252 | KAN (loss/acc/sat): 0.487/0.676/0.513(0.514)
# Epoch 253 | KAN (loss/acc/sat): 0.486/0.677/0.514(0.514)
# Epoch 254 | KAN (loss/acc/sat): 0.486/0.677/0.514(0.515)
# Epoch 255 | KAN (loss/acc/sat): 0.485/0.678/0.515(0.516)
# Epoch 256 | KAN (loss/acc/sat): 0.485/0.678/0.515(0.516)
# Epoch 257 | KAN (loss/acc/sat): 0.484/0.679/0.516(0.517)
# Epoch 258 | KAN (loss/acc/sat): 0.483/0.679/0.517(0.517)
# Epoch 259 | KAN (loss/acc/sat): 0.483/0.680/0.517(0.518)
# Epoch 260 | KAN (loss/acc/sat): 0.482/0.680/0.518(0.519)
# Epoch 261 | KAN (loss/acc/sat): 0.481/0.681/0.519(0.519)
# Epoch 262 | KAN (loss/acc/sat): 0.481/0.682/0.519(0.520)
# Epoch 263 | KAN (loss/acc/sat): 0.480/0.683/0.520(0.520)
# Epoch 264 | KAN (loss/acc/sat): 0.480/0.683/0.520(0.521)
# Epoch 265 | KAN (loss/acc/sat): 0.479/0.683/0.521(0.521)
# Epoch 266 | KAN (loss/acc/sat): 0.478/0.683/0.522(0.522)
# Epoch 267 | KAN (loss/acc/sat): 0.478/0.685/0.522(0.523)
# Epoch 268 | KAN (loss/acc/sat): 0.477/0.684/0.523(0.523)
# Epoch 269 | KAN (loss/acc/sat): 0.477/0.685/0.523(0.524)
# Epoch 270 | KAN (loss/acc/sat): 0.476/0.686/0.524(0.524)
# Epoch 271 | KAN (loss/acc/sat): 0.476/0.686/0.524(0.525)
# Epoch 272 | KAN (loss/acc/sat): 0.475/0.688/0.525(0.525)
# Epoch 273 | KAN (loss/acc/sat): 0.475/0.689/0.525(0.526)
# Epoch 274 | KAN (loss/acc/sat): 0.474/0.689/0.526(0.526)
# Epoch 275 | KAN (loss/acc/sat): 0.474/0.690/0.526(0.527)
# Epoch 276 | KAN (loss/acc/sat): 0.473/0.691/0.527(0.527)
# Epoch 277 | KAN (loss/acc/sat): 0.473/0.692/0.527(0.528)
# Epoch 278 | KAN (loss/acc/sat): 0.472/0.693/0.528(0.528)
# Epoch 279 | KAN (loss/acc/sat): 0.471/0.695/0.529(0.529)
# Epoch 280 | KAN (loss/acc/sat): 0.471/0.695/0.529(0.529)
# Epoch 281 | KAN (loss/acc/sat): 0.470/0.696/0.530(0.530)
# Epoch 282 | KAN (loss/acc/sat): 0.470/0.697/0.530(0.530)
# Epoch 283 | KAN (loss/acc/sat): 0.470/0.700/0.530(0.531)
# Epoch 361 | KAN (loss/acc/sat): 0.439/0.755/0.561(0.559)
# Epoch 362 | KAN (loss/acc/sat): 0.438/0.756/0.562(0.560)
# Epoch 363 | KAN (loss/acc/sat): 0.438/0.757/0.562(0.560)
# Epoch 364 | KAN (loss/acc/sat): 0.438/0.757/0.562(0.560)
# Epoch 365 | KAN (loss/acc/sat): 0.437/0.757/0.563(0.561)
# Epoch 366 | KAN (loss/acc/sat): 0.437/0.758/0.563(0.561)
# Epoch 367 | KAN (loss/acc/sat): 0.437/0.759/0.563(0.561)
# Epoch 368 | KAN (loss/acc/sat): 0.436/0.760/0.564(0.562)
# Epoch 369 | KAN (loss/acc/sat): 0.436/0.761/0.564(0.562)
# Epoch 370 | KAN (loss/acc/sat): 0.436/0.762/0.564(0.562)
# Epoch 371 | KAN (loss/acc/sat): 0.435/0.764/0.565(0.563)
# Epoch 372 | KAN (loss/acc/sat): 0.435/0.765/0.565(0.563)
# Epoch 373 | KAN (loss/acc/sat): 0.435/0.767/0.565(0.563)
# Epoch 374 | KAN (loss/acc/sat): 0.434/0.767/0.566(0.563)
# Epoch 375 | KAN (loss/acc/sat): 0.434/0.767/0.566(0.564)
# Epoch 376 | KAN (loss/acc/sat): 0.434/0.768/0.566(0.564)
# Epoch 377 | KAN (loss/acc/sat): 0.433/0.768/0.567(0.564)
# Epoch 378 | KAN (loss/acc/sat): 0.433/0.768/0.567(0.565)
# Epoch 379 | KAN (loss/acc/sat): 0.433/0.769/0.567(0.565)
# Epoch 380 | KAN (loss/acc/sat): 0.432/0.770/0.568(0.565)
# Epoch 381 | KAN (loss/acc/sat): 0.432/0.770/0.568(0.566)
# Epoch 382 | KAN (loss/acc/sat): 0.432/0.770/0.568(0.566)
# Epoch 383 | KAN (loss/acc/sat): 0.431/0.771/0.569(0.566)
# Epoch 384 | KAN (loss/acc/sat): 0.431/0.772/0.569(0.566)
# Epoch 385 | KAN (loss/acc/sat): 0.431/0.773/0.569(0.567)
# Epoch 386 | KAN (loss/acc/sat): 0.430/0.775/0.570(0.567)
# Epoch 387 | KAN (loss/acc/sat): 0.430/0.776/0.570(0.567)
# Epoch 388 | KAN (loss/acc/sat): 0.430/0.776/0.570(0.568)
# Epoch 389 | KAN (loss/acc/sat): 0.429/0.777/0.571(0.568)
# Epoch 390 | KAN (loss/acc/sat): 0.429/0.778/0.571(0.568)
# Epoch 391 | KAN (loss/acc/sat): 0.429/0.778/0.571(0.569)
# Epoch 392 | KAN (loss/acc/sat): 0.429/0.779/0.571(0.569)
# Epoch 393 | KAN (loss/acc/sat): 0.428/0.779/0.572(0.569)
# Epoch 394 | KAN (loss/acc/sat): 0.428/0.781/0.572(0.569)
# Epoch 395 | KAN (loss/acc/sat): 0.428/0.781/0.572(0.570)
# Epoch 396 | KAN (loss/acc/sat): 0.427/0.781/0.573(0.570)
# Epoch 397 | KAN (loss/acc/sat): 0.427/0.782/0.573(0.570)
# Epoch 398 | KAN (loss/acc/sat): 0.427/0.782/0.573(0.571)
# Epoch 399 | KAN (loss/acc/sat): 0.426/0.782/0.574(0.571)
# Epoch 400 | KAN (loss/acc/sat): 0.426/0.782/0.574(0.571)
# Training finished.

# %%
def load_model_state(infer_model, model_save_folder, model_name):
    """
    Load the model from disk.
    """
    checkpoint = torch.load(os.path.join(model_save_folder, model_name), 
                            map_location=device)
    infer_model.load_state_dict(checkpoint)
    infer_model.eval()
    return infer_model

# Load the model
logiKNet_infer = KAN(width=[18, 10, 6], grid=5, k=3, seed=42, device=device)
logiKNet_infer = load_model_state(logiKNet_infer, model_state_folder, 'logiKNet.pt')
# Test the model
with torch.no_grad():
    for data, labels in test_loader:
        logits = logiKNet_infer(data)
        preds = torch.argmax(logits, dim=1)
        print(f"Predictions: {preds}, Labels: {labels}")
        
        logiKNet_infer_acc = compute_accuracy(test_loader, logiKNet_infer)
        print(f"Test accuracy of the loaded model: {logiKNet_infer_acc.item()}")
        break
# Out:
# checkpoint directory created: ./model
# saving model version 0.0
# Predictions: tensor([2, 2, 0,  ..., 2, 4, 2]), Labels: tensor([2, 0, 0,  ..., 2, 4, 2])
# Test accuracy of the loaded model: 0.7819228768348694
# /tmp/ipykernel_1298114/1172964025.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(os.path.join(model_save_folder, model_name),

# %% [markdown]
# **hierarchical-logiKNet**

# %%
def compute_sat_levels(loader, P):
	sat_level  = 0
	for data, labels in loader:
		x = ltn.Variable("x", data)
		x_MQTT_DDoS_Connect_Flood = ltn.Variable("x_MQTT_DDoS_Connect_Flood", data[labels == 0])
		x_MQTT_DDoS_Publish_Flood = ltn.Variable("x_MQTT_DDoS_Publish_Flood", data[labels == 1])
		x_MQTT_DoS_Connect_Flood = ltn.Variable("x_MQTT_DoS_Connect_Flood", data[labels == 2])
		x_MQTT_DoS_Publish_Flood = ltn.Variable("x_MQTT_DoS_Publish_Flood", data[labels == 3])
		x_MQTT_Malformed_Data = ltn.Variable("x_MQTT_Malformed_Data", data[labels == 4])
		x_Benign = ltn.Variable("x_Benign", data[labels == 5])
		######################
		x_MQTT = ltn.Variable("x_MQTT", data[labels < 5]) 
		######################
		
		sat_level = SatAgg(
			Forall(x_MQTT_DDoS_Connect_Flood, P(x_MQTT_DDoS_Connect_Flood, l_MQTT_DDoS_Connect_Flood)),
			Forall(x_MQTT_DDoS_Publish_Flood, P(x_MQTT_DDoS_Publish_Flood, l_MQTT_DDoS_Publish_Flood)),
			Forall(x_MQTT_DoS_Connect_Flood, P(x_MQTT_DoS_Connect_Flood, l_MQTT_DoS_Connect_Flood)),
			Forall(x_MQTT_DoS_Publish_Flood, P(x_MQTT_DoS_Publish_Flood, l_MQTT_DoS_Publish_Flood)),
			Forall(x_MQTT_Malformed_Data, P(x_MQTT_Malformed_Data, l_MQTT_Malformed_Data)),
			Forall(x_Benign, P(x_Benign, l_Benign)),
			# hierarchical constraints
			Forall(x_MQTT, Not(P(x_MQTT, l_Benign)))
		)
	return sat_level

kan_h = KAN(width=[18, 10, 6], grid=5, k=3, seed=42, device=device)
P_kan_h = ltn.Predicate(LogitsToPredicate(MultiKANModel(kan_h)))

optimizer_kan = torch.optim.Adam(P_kan_h.parameters(), lr=0.001)

for epoch in range(401):
	optimizer_kan.zero_grad()
	sat_kan = compute_sat_levels(train_loader, P_kan_h)
	loss = 1. - sat_kan
	loss.backward()
	optimizer_kan.step()
	train_loss_kan = loss.item()

	# Test the KAN
	test_acc_kan = compute_accuracy(test_loader, kan_h)
	test_sat_kan = compute_sat_levels(test_loader, P_kan_h)

	print(f"Epoch {epoch} | KAN (loss/acc/sat): {train_loss_kan:.3f}/{test_acc_kan:.3f}/{sat_kan:.3f}({test_sat_kan:.3f})")

print("Training finished.")

# save the models as .pt files
save_model(kan_h, model_state_folder, 'hierarchical_logiKNet.pt')
# Out:
# checkpoint directory created: ./model
# saving model version 0.0
# Epoch 0 | KAN (loss/acc/sat): 0.775/0.275/0.225(0.226)
# Epoch 1 | KAN (loss/acc/sat): 0.774/0.287/0.226(0.227)
# Epoch 2 | KAN (loss/acc/sat): 0.774/0.300/0.226(0.227)
# Epoch 3 | KAN (loss/acc/sat): 0.773/0.312/0.227(0.228)
# Epoch 4 | KAN (loss/acc/sat): 0.772/0.324/0.228(0.228)
# Epoch 5 | KAN (loss/acc/sat): 0.772/0.336/0.228(0.229)
# Epoch 6 | KAN (loss/acc/sat): 0.771/0.348/0.229(0.230)
# Epoch 7 | KAN (loss/acc/sat): 0.770/0.354/0.230(0.230)
# Epoch 8 | KAN (loss/acc/sat): 0.770/0.360/0.230(0.231)
# Epoch 9 | KAN (loss/acc/sat): 0.769/0.364/0.231(0.232)
# Epoch 10 | KAN (loss/acc/sat): 0.768/0.368/0.232(0.232)
# Epoch 11 | KAN (loss/acc/sat): 0.768/0.381/0.232(0.233)
# Epoch 12 | KAN (loss/acc/sat): 0.767/0.387/0.233(0.234)
# Epoch 13 | KAN (loss/acc/sat): 0.766/0.395/0.234(0.235)
# Epoch 14 | KAN (loss/acc/sat): 0.766/0.403/0.234(0.235)
# Epoch 15 | KAN (loss/acc/sat): 0.765/0.410/0.235(0.236)
# Epoch 16 | KAN (loss/acc/sat): 0.764/0.418/0.236(0.237)
# Epoch 17 | KAN (loss/acc/sat): 0.764/0.427/0.236(0.238)
# Epoch 18 | KAN (loss/acc/sat): 0.763/0.432/0.237(0.238)
# Epoch 19 | KAN (loss/acc/sat): 0.762/0.436/0.238(0.239)
# Epoch 20 | KAN (loss/acc/sat): 0.761/0.441/0.239(0.240)
# Epoch 21 | KAN (loss/acc/sat): 0.761/0.447/0.239(0.241)
# Epoch 22 | KAN (loss/acc/sat): 0.760/0.461/0.240(0.241)
# Epoch 23 | KAN (loss/acc/sat): 0.759/0.468/0.241(0.242)
# Epoch 24 | KAN (loss/acc/sat): 0.758/0.476/0.242(0.243)
# Epoch 25 | KAN (loss/acc/sat): 0.757/0.482/0.243(0.244)
# Epoch 26 | KAN (loss/acc/sat): 0.757/0.486/0.243(0.245)
# Epoch 27 | KAN (loss/acc/sat): 0.756/0.489/0.244(0.246)
# Epoch 28 | KAN (loss/acc/sat): 0.755/0.491/0.245(0.246)
# Epoch 29 | KAN (loss/acc/sat): 0.754/0.492/0.246(0.247)
# Epoch 30 | KAN (loss/acc/sat): 0.753/0.491/0.247(0.248)
# Epoch 31 | KAN (loss/acc/sat): 0.752/0.492/0.248(0.249)
# Epoch 32 | KAN (loss/acc/sat): 0.752/0.492/0.248(0.250)
# Epoch 33 | KAN (loss/acc/sat): 0.751/0.492/0.249(0.251)
# Epoch 34 | KAN (loss/acc/sat): 0.750/0.492/0.250(0.252)
# Epoch 35 | KAN (loss/acc/sat): 0.749/0.493/0.251(0.253)
# Epoch 36 | KAN (loss/acc/sat): 0.748/0.493/0.252(0.254)
# Epoch 37 | KAN (loss/acc/sat): 0.747/0.493/0.253(0.255)
# Epoch 38 | KAN (loss/acc/sat): 0.746/0.495/0.254(0.256)
# Epoch 39 | KAN (loss/acc/sat): 0.745/0.495/0.255(0.257)
# Epoch 40 | KAN (loss/acc/sat): 0.744/0.494/0.256(0.258)
# Epoch 41 | KAN (loss/acc/sat): 0.743/0.495/0.257(0.259)
# Epoch 42 | KAN (loss/acc/sat): 0.742/0.494/0.258(0.260)
# Epoch 43 | KAN (loss/acc/sat): 0.741/0.494/0.259(0.261)
# Epoch 44 | KAN (loss/acc/sat): 0.740/0.494/0.260(0.262)
# Epoch 45 | KAN (loss/acc/sat): 0.739/0.494/0.261(0.263)
# Epoch 46 | KAN (loss/acc/sat): 0.738/0.494/0.262(0.264)
# Epoch 47 | KAN (loss/acc/sat): 0.737/0.493/0.263(0.265)
# Epoch 48 | KAN (loss/acc/sat): 0.736/0.493/0.264(0.267)
# Epoch 49 | KAN (loss/acc/sat): 0.735/0.493/0.265(0.268)
# Epoch 50 | KAN (loss/acc/sat): 0.734/0.493/0.266(0.269)
# Epoch 51 | KAN (loss/acc/sat): 0.732/0.493/0.268(0.270)
# Epoch 52 | KAN (loss/acc/sat): 0.731/0.494/0.269(0.271)
# Epoch 53 | KAN (loss/acc/sat): 0.730/0.494/0.270(0.272)
# Epoch 54 | KAN (loss/acc/sat): 0.729/0.494/0.271(0.274)
# Epoch 55 | KAN (loss/acc/sat): 0.728/0.494/0.272(0.275)
# Epoch 56 | KAN (loss/acc/sat): 0.727/0.495/0.273(0.276)
# Epoch 57 | KAN (loss/acc/sat): 0.726/0.496/0.274(0.277)
# Epoch 58 | KAN (loss/acc/sat): 0.724/0.497/0.276(0.278)
# Epoch 59 | KAN (loss/acc/sat): 0.723/0.497/0.277(0.280)
# Epoch 60 | KAN (loss/acc/sat): 0.722/0.499/0.278(0.281)
# Epoch 61 | KAN (loss/acc/sat): 0.721/0.502/0.279(0.282)
# Epoch 62 | KAN (loss/acc/sat): 0.719/0.502/0.281(0.283)
# Epoch 63 | KAN (loss/acc/sat): 0.718/0.502/0.282(0.285)
# Epoch 64 | KAN (loss/acc/sat): 0.717/0.502/0.283(0.286)
# Epoch 65 | KAN (loss/acc/sat): 0.716/0.503/0.284(0.287)
# Epoch 66 | KAN (loss/acc/sat): 0.714/0.503/0.286(0.289)
# Epoch 67 | KAN (loss/acc/sat): 0.713/0.504/0.287(0.290)
# Epoch 68 | KAN (loss/acc/sat): 0.712/0.504/0.288(0.291)
# Epoch 69 | KAN (loss/acc/sat): 0.710/0.504/0.290(0.293)
# Epoch 70 | KAN (loss/acc/sat): 0.709/0.505/0.291(0.294)
# Epoch 71 | KAN (loss/acc/sat): 0.708/0.505/0.292(0.296)
# Epoch 72 | KAN (loss/acc/sat): 0.706/0.505/0.294(0.297)
# Epoch 73 | KAN (loss/acc/sat): 0.705/0.504/0.295(0.299)
# Epoch 74 | KAN (loss/acc/sat): 0.703/0.504/0.297(0.300)
# Epoch 75 | KAN (loss/acc/sat): 0.702/0.506/0.298(0.302)
# Epoch 76 | KAN (loss/acc/sat): 0.700/0.506/0.300(0.303)
# Epoch 77 | KAN (loss/acc/sat): 0.699/0.507/0.301(0.305)
# Epoch 78 | KAN (loss/acc/sat): 0.697/0.508/0.303(0.306)
# Epoch 79 | KAN (loss/acc/sat): 0.696/0.508/0.304(0.308)
# Epoch 80 | KAN (loss/acc/sat): 0.694/0.507/0.306(0.309)
# Epoch 81 | KAN (loss/acc/sat): 0.693/0.508/0.307(0.311)
# Epoch 82 | KAN (loss/acc/sat): 0.691/0.508/0.309(0.312)
# Epoch 83 | KAN (loss/acc/sat): 0.690/0.509/0.310(0.314)
# Epoch 84 | KAN (loss/acc/sat): 0.688/0.510/0.312(0.316)
# Epoch 85 | KAN (loss/acc/sat): 0.686/0.510/0.314(0.317)
# Epoch 86 | KAN (loss/acc/sat): 0.685/0.511/0.315(0.319)
# Epoch 87 | KAN (loss/acc/sat): 0.683/0.509/0.317(0.321)
# Epoch 88 | KAN (loss/acc/sat): 0.681/0.510/0.319(0.322)
# Epoch 89 | KAN (loss/acc/sat): 0.680/0.510/0.320(0.324)
# Epoch 90 | KAN (loss/acc/sat): 0.678/0.509/0.322(0.326)
# Epoch 91 | KAN (loss/acc/sat): 0.676/0.511/0.324(0.328)
# Epoch 92 | KAN (loss/acc/sat): 0.675/0.511/0.325(0.329)
# Epoch 93 | KAN (loss/acc/sat): 0.673/0.511/0.327(0.331)
# Epoch 94 | KAN (loss/acc/sat): 0.671/0.510/0.329(0.333)
# Epoch 95 | KAN (loss/acc/sat): 0.670/0.512/0.330(0.334)
# Epoch 96 | KAN (loss/acc/sat): 0.668/0.512/0.332(0.336)
# Epoch 97 | KAN (loss/acc/sat): 0.666/0.513/0.334(0.338)
# Epoch 98 | KAN (loss/acc/sat): 0.664/0.514/0.336(0.340)
# Epoch 99 | KAN (loss/acc/sat): 0.663/0.514/0.337(0.341)
# Epoch 100 | KAN (loss/acc/sat): 0.661/0.515/0.339(0.343)
# Epoch 101 | KAN (loss/acc/sat): 0.659/0.515/0.341(0.345)
# Epoch 102 | KAN (loss/acc/sat): 0.657/0.515/0.343(0.347)
# Epoch 103 | KAN (loss/acc/sat): 0.656/0.515/0.344(0.348)
# Epoch 104 | KAN (loss/acc/sat): 0.654/0.516/0.346(0.350)
# Epoch 105 | KAN (loss/acc/sat): 0.652/0.518/0.348(0.352)
# Epoch 106 | KAN (loss/acc/sat): 0.651/0.518/0.349(0.354)
# Epoch 107 | KAN (loss/acc/sat): 0.649/0.518/0.351(0.355)
# Epoch 108 | KAN (loss/acc/sat): 0.647/0.518/0.353(0.357)
# Epoch 109 | KAN (loss/acc/sat): 0.645/0.519/0.355(0.359)
# Epoch 110 | KAN (loss/acc/sat): 0.644/0.518/0.356(0.361)
# Epoch 111 | KAN (loss/acc/sat): 0.642/0.518/0.358(0.362)
# Epoch 112 | KAN (loss/acc/sat): 0.640/0.520/0.360(0.364)
# Epoch 113 | KAN (loss/acc/sat): 0.639/0.520/0.361(0.366)
# Epoch 114 | KAN (loss/acc/sat): 0.637/0.521/0.363(0.368)
# Epoch 115 | KAN (loss/acc/sat): 0.635/0.522/0.365(0.369)
# Epoch 116 | KAN (loss/acc/sat): 0.634/0.522/0.366(0.371)
# Epoch 117 | KAN (loss/acc/sat): 0.632/0.523/0.368(0.373)
# Epoch 118 | KAN (loss/acc/sat): 0.630/0.523/0.370(0.374)
# Epoch 119 | KAN (loss/acc/sat): 0.629/0.524/0.371(0.376)
# Epoch 120 | KAN (loss/acc/sat): 0.627/0.524/0.373(0.378)
# Epoch 121 | KAN (loss/acc/sat): 0.625/0.525/0.375(0.379)
# Epoch 122 | KAN (loss/acc/sat): 0.624/0.526/0.376(0.381)
# Epoch 123 | KAN (loss/acc/sat): 0.622/0.527/0.378(0.383)
# Epoch 124 | KAN (loss/acc/sat): 0.620/0.529/0.380(0.384)
# Epoch 125 | KAN (loss/acc/sat): 0.619/0.530/0.381(0.386)
# Epoch 126 | KAN (loss/acc/sat): 0.617/0.531/0.383(0.387)
# Epoch 127 | KAN (loss/acc/sat): 0.615/0.533/0.385(0.389)
# Epoch 128 | KAN (loss/acc/sat): 0.614/0.533/0.386(0.391)
# Epoch 129 | KAN (loss/acc/sat): 0.612/0.535/0.388(0.392)
# Epoch 130 | KAN (loss/acc/sat): 0.611/0.535/0.389(0.394)
# Epoch 131 | KAN (loss/acc/sat): 0.609/0.537/0.391(0.395)
# Epoch 132 | KAN (loss/acc/sat): 0.608/0.538/0.392(0.397)
# Epoch 133 | KAN (loss/acc/sat): 0.606/0.539/0.394(0.398)
# Epoch 134 | KAN (loss/acc/sat): 0.605/0.539/0.395(0.400)
# Epoch 135 | KAN (loss/acc/sat): 0.603/0.539/0.397(0.401)
# Epoch 136 | KAN (loss/acc/sat): 0.601/0.541/0.399(0.403)
# Epoch 137 | KAN (loss/acc/sat): 0.600/0.543/0.400(0.405)
# Epoch 138 | KAN (loss/acc/sat): 0.598/0.544/0.402(0.406)
# Epoch 139 | KAN (loss/acc/sat): 0.597/0.546/0.403(0.408)
# Epoch 140 | KAN (loss/acc/sat): 0.595/0.547/0.405(0.409)
# Epoch 141 | KAN (loss/acc/sat): 0.594/0.548/0.406(0.411)
# Epoch 142 | KAN (loss/acc/sat): 0.592/0.550/0.408(0.412)
# Epoch 143 | KAN (loss/acc/sat): 0.591/0.550/0.409(0.414)
# Epoch 144 | KAN (loss/acc/sat): 0.589/0.551/0.411(0.415)
# Epoch 145 | KAN (loss/acc/sat): 0.588/0.551/0.412(0.416)
# Epoch 146 | KAN (loss/acc/sat): 0.586/0.552/0.414(0.418)
# Epoch 147 | KAN (loss/acc/sat): 0.585/0.553/0.415(0.419)
# Epoch 148 | KAN (loss/acc/sat): 0.583/0.555/0.417(0.421)
# Epoch 149 | KAN (loss/acc/sat): 0.582/0.555/0.418(0.422)
# Epoch 150 | KAN (loss/acc/sat): 0.580/0.556/0.420(0.424)
# Epoch 151 | KAN (loss/acc/sat): 0.579/0.557/0.421(0.425)
# Epoch 152 | KAN (loss/acc/sat): 0.577/0.559/0.423(0.427)
# Epoch 153 | KAN (loss/acc/sat): 0.576/0.561/0.424(0.428)
# Epoch 154 | KAN (loss/acc/sat): 0.574/0.561/0.426(0.430)
# Epoch 155 | KAN (loss/acc/sat): 0.573/0.562/0.427(0.431)
# Epoch 156 | KAN (loss/acc/sat): 0.571/0.564/0.429(0.433)
# Epoch 157 | KAN (loss/acc/sat): 0.570/0.566/0.430(0.434)
# Epoch 158 | KAN (loss/acc/sat): 0.568/0.568/0.432(0.436)
# Epoch 159 | KAN (loss/acc/sat): 0.567/0.570/0.433(0.437)
# Epoch 160 | KAN (loss/acc/sat): 0.565/0.570/0.435(0.439)
# Epoch 161 | KAN (loss/acc/sat): 0.564/0.573/0.436(0.440)
# Epoch 162 | KAN (loss/acc/sat): 0.562/0.575/0.438(0.442)
# Epoch 163 | KAN (loss/acc/sat): 0.561/0.579/0.439(0.443)
# Epoch 164 | KAN (loss/acc/sat): 0.559/0.580/0.441(0.445)
# Epoch 165 | KAN (loss/acc/sat): 0.558/0.582/0.442(0.446)
# Epoch 166 | KAN (loss/acc/sat): 0.556/0.584/0.444(0.448)
# Epoch 167 | KAN (loss/acc/sat): 0.554/0.587/0.446(0.449)
# Epoch 168 | KAN (loss/acc/sat): 0.553/0.591/0.447(0.451)
# Epoch 169 | KAN (loss/acc/sat): 0.551/0.596/0.449(0.452)
# Epoch 170 | KAN (loss/acc/sat): 0.550/0.600/0.450(0.454)
# Epoch 171 | KAN (loss/acc/sat): 0.548/0.605/0.452(0.455)
# Epoch 172 | KAN (loss/acc/sat): 0.547/0.609/0.453(0.457)
# Epoch 173 | KAN (loss/acc/sat): 0.545/0.614/0.455(0.458)
# Epoch 174 | KAN (loss/acc/sat): 0.543/0.616/0.457(0.460)
# Epoch 175 | KAN (loss/acc/sat): 0.542/0.620/0.458(0.461)
# Epoch 176 | KAN (loss/acc/sat): 0.540/0.623/0.460(0.463)
# Epoch 177 | KAN (loss/acc/sat): 0.539/0.626/0.461(0.464)
# Epoch 178 | KAN (loss/acc/sat): 0.537/0.632/0.463(0.466)
# Epoch 179 | KAN (loss/acc/sat): 0.535/0.633/0.465(0.468)
# Epoch 180 | KAN (loss/acc/sat): 0.534/0.637/0.466(0.469)
# Epoch 181 | KAN (loss/acc/sat): 0.532/0.640/0.468(0.471)
# Epoch 182 | KAN (loss/acc/sat): 0.531/0.643/0.469(0.472)
# Epoch 183 | KAN (loss/acc/sat): 0.529/0.644/0.471(0.474)
# Epoch 184 | KAN (loss/acc/sat): 0.527/0.645/0.473(0.475)
# Epoch 185 | KAN (loss/acc/sat): 0.526/0.647/0.474(0.477)
# Epoch 186 | KAN (loss/acc/sat): 0.524/0.649/0.476(0.478)
# Epoch 187 | KAN (loss/acc/sat): 0.523/0.651/0.477(0.480)
# Epoch 188 | KAN (loss/acc/sat): 0.521/0.653/0.479(0.481)
# Epoch 189 | KAN (loss/acc/sat): 0.520/0.655/0.480(0.483)
# Epoch 190 | KAN (loss/acc/sat): 0.518/0.655/0.482(0.484)
# Epoch 191 | KAN (loss/acc/sat): 0.517/0.656/0.483(0.486)
# Epoch 192 | KAN (loss/acc/sat): 0.515/0.655/0.485(0.487)
# Epoch 193 | KAN (loss/acc/sat): 0.514/0.656/0.486(0.489)
# Epoch 194 | KAN (loss/acc/sat): 0.512/0.657/0.488(0.490)
# Epoch 195 | KAN (loss/acc/sat): 0.511/0.658/0.489(0.491)
# Epoch 196 | KAN (loss/acc/sat): 0.509/0.657/0.491(0.493)
# Epoch 197 | KAN (loss/acc/sat): 0.508/0.658/0.492(0.494)
# Epoch 198 | KAN (loss/acc/sat): 0.506/0.659/0.494(0.496)
# Epoch 199 | KAN (loss/acc/sat): 0.505/0.660/0.495(0.497)
# Epoch 200 | KAN (loss/acc/sat): 0.504/0.660/0.496(0.498)
# Epoch 201 | KAN (loss/acc/sat): 0.502/0.662/0.498(0.500)
# Epoch 202 | KAN (loss/acc/sat): 0.501/0.662/0.499(0.501)
# Epoch 203 | KAN (loss/acc/sat): 0.500/0.663/0.500(0.502)
# Epoch 204 | KAN (loss/acc/sat): 0.498/0.663/0.502(0.504)
# Epoch 205 | KAN (loss/acc/sat): 0.497/0.663/0.503(0.505)
# Epoch 206 | KAN (loss/acc/sat): 0.496/0.664/0.504(0.506)
# Epoch 207 | KAN (loss/acc/sat): 0.494/0.664/0.506(0.507)
# Epoch 208 | KAN (loss/acc/sat): 0.493/0.665/0.507(0.509)
# Epoch 209 | KAN (loss/acc/sat): 0.492/0.665/0.508(0.510)
# Epoch 210 | KAN (loss/acc/sat): 0.491/0.665/0.509(0.511)
# Epoch 211 | KAN (loss/acc/sat): 0.489/0.666/0.511(0.512)
# Epoch 212 | KAN (loss/acc/sat): 0.488/0.666/0.512(0.513)
# Epoch 213 | KAN (loss/acc/sat): 0.487/0.667/0.513(0.514)
# Epoch 214 | KAN (loss/acc/sat): 0.486/0.668/0.514(0.515)
# Epoch 215 | KAN (loss/acc/sat): 0.485/0.668/0.515(0.516)
# Epoch 216 | KAN (loss/acc/sat): 0.484/0.669/0.516(0.518)
# Epoch 217 | KAN (loss/acc/sat): 0.483/0.669/0.517(0.519)
# Epoch 218 | KAN (loss/acc/sat): 0.482/0.670/0.518(0.520)
# Epoch 219 | KAN (loss/acc/sat): 0.481/0.669/0.519(0.521)
# Epoch 220 | KAN (loss/acc/sat): 0.480/0.670/0.520(0.522)
# Epoch 221 | KAN (loss/acc/sat): 0.479/0.670/0.521(0.523)
# Epoch 222 | KAN (loss/acc/sat): 0.478/0.671/0.522(0.524)
# Epoch 223 | KAN (loss/acc/sat): 0.477/0.671/0.523(0.525)
# Epoch 224 | KAN (loss/acc/sat): 0.476/0.671/0.524(0.525)
# Epoch 225 | KAN (loss/acc/sat): 0.475/0.672/0.525(0.526)
# Epoch 226 | KAN (loss/acc/sat): 0.474/0.673/0.526(0.527)
# Epoch 227 | KAN (loss/acc/sat): 0.473/0.673/0.527(0.528)
# Epoch 228 | KAN (loss/acc/sat): 0.472/0.673/0.528(0.529)
# Epoch 229 | KAN (loss/acc/sat): 0.471/0.673/0.529(0.530)
# Epoch 230 | KAN (loss/acc/sat): 0.470/0.673/0.530(0.531)
# Epoch 231 | KAN (loss/acc/sat): 0.469/0.674/0.531(0.531)
# Epoch 232 | KAN (loss/acc/sat): 0.469/0.674/0.531(0.532)
# Epoch 233 | KAN (loss/acc/sat): 0.468/0.675/0.532(0.533)
# Epoch 234 | KAN (loss/acc/sat): 0.467/0.675/0.533(0.534)
# Epoch 235 | KAN (loss/acc/sat): 0.466/0.675/0.534(0.535)
# Epoch 236 | KAN (loss/acc/sat): 0.465/0.675/0.535(0.535)
# Epoch 237 | KAN (loss/acc/sat): 0.465/0.675/0.535(0.536)
# Epoch 238 | KAN (loss/acc/sat): 0.464/0.675/0.536(0.537)
# Epoch 239 | KAN (loss/acc/sat): 0.463/0.675/0.537(0.538)
# Epoch 240 | KAN (loss/acc/sat): 0.462/0.675/0.538(0.538)
# Epoch 241 | KAN (loss/acc/sat): 0.462/0.675/0.538(0.539)
# Epoch 242 | KAN (loss/acc/sat): 0.461/0.675/0.539(0.540)
# Epoch 243 | KAN (loss/acc/sat): 0.460/0.675/0.540(0.540)
# Epoch 244 | KAN (loss/acc/sat): 0.459/0.675/0.541(0.541)
# Epoch 245 | KAN (loss/acc/sat): 0.459/0.675/0.541(0.542)
# Epoch 246 | KAN (loss/acc/sat): 0.458/0.676/0.542(0.542)
# Epoch 247 | KAN (loss/acc/sat): 0.457/0.677/0.543(0.543)
# Epoch 248 | KAN (loss/acc/sat): 0.457/0.678/0.543(0.544)
# Epoch 249 | KAN (loss/acc/sat): 0.456/0.678/0.544(0.544)
# Epoch 250 | KAN (loss/acc/sat): 0.455/0.679/0.545(0.545)
# Epoch 251 | KAN (loss/acc/sat): 0.455/0.679/0.545(0.546)
# Epoch 252 | KAN (loss/acc/sat): 0.454/0.679/0.546(0.546)
# Epoch 253 | KAN (loss/acc/sat): 0.453/0.680/0.547(0.547)
# Epoch 254 | KAN (loss/acc/sat): 0.453/0.679/0.547(0.547)
# Epoch 255 | KAN (loss/acc/sat): 0.452/0.679/0.548(0.548)
# Epoch 256 | KAN (loss/acc/sat): 0.452/0.680/0.548(0.548)
# Epoch 257 | KAN (loss/acc/sat): 0.451/0.680/0.549(0.549)
# Epoch 258 | KAN (loss/acc/sat): 0.450/0.681/0.550(0.550)
# Epoch 259 | KAN (loss/acc/sat): 0.450/0.682/0.550(0.550)
# Epoch 260 | KAN (loss/acc/sat): 0.449/0.682/0.551(0.551)
# Epoch 338 | KAN (loss/acc/sat): 0.416/0.756/0.584(0.583)
# Epoch 339 | KAN (loss/acc/sat): 0.415/0.756/0.585(0.583)
# Epoch 340 | KAN (loss/acc/sat): 0.415/0.757/0.585(0.583)
# Epoch 341 | KAN (loss/acc/sat): 0.415/0.758/0.585(0.584)
# Epoch 342 | KAN (loss/acc/sat): 0.414/0.758/0.586(0.584)
# Epoch 343 | KAN (loss/acc/sat): 0.414/0.758/0.586(0.584)
# Epoch 344 | KAN (loss/acc/sat): 0.414/0.758/0.586(0.585)
# Epoch 345 | KAN (loss/acc/sat): 0.413/0.759/0.587(0.585)
# Epoch 346 | KAN (loss/acc/sat): 0.413/0.760/0.587(0.585)
# Epoch 347 | KAN (loss/acc/sat): 0.413/0.760/0.587(0.586)
# Epoch 348 | KAN (loss/acc/sat): 0.412/0.761/0.588(0.586)
# Epoch 349 | KAN (loss/acc/sat): 0.412/0.761/0.588(0.586)
# Epoch 350 | KAN (loss/acc/sat): 0.412/0.762/0.588(0.587)
# Epoch 351 | KAN (loss/acc/sat): 0.411/0.762/0.589(0.587)
# Epoch 352 | KAN (loss/acc/sat): 0.411/0.762/0.589(0.587)
# Epoch 353 | KAN (loss/acc/sat): 0.411/0.762/0.589(0.588)
# Epoch 354 | KAN (loss/acc/sat): 0.410/0.762/0.590(0.588)
# Epoch 355 | KAN (loss/acc/sat): 0.410/0.764/0.590(0.588)
# Epoch 356 | KAN (loss/acc/sat): 0.409/0.764/0.591(0.589)
# Epoch 357 | KAN (loss/acc/sat): 0.409/0.765/0.591(0.589)
# Epoch 358 | KAN (loss/acc/sat): 0.409/0.766/0.591(0.589)
# Epoch 359 | KAN (loss/acc/sat): 0.408/0.767/0.592(0.589)
# Epoch 360 | KAN (loss/acc/sat): 0.408/0.768/0.592(0.590)
# Epoch 361 | KAN (loss/acc/sat): 0.408/0.770/0.592(0.590)
# Epoch 362 | KAN (loss/acc/sat): 0.407/0.772/0.593(0.590)
# Epoch 363 | KAN (loss/acc/sat): 0.407/0.773/0.593(0.591)
# Epoch 364 | KAN (loss/acc/sat): 0.407/0.775/0.593(0.591)
# Epoch 365 | KAN (loss/acc/sat): 0.406/0.776/0.594(0.591)
# Epoch 366 | KAN (loss/acc/sat): 0.406/0.777/0.594(0.592)
# Epoch 367 | KAN (loss/acc/sat): 0.406/0.777/0.594(0.592)
# Epoch 368 | KAN (loss/acc/sat): 0.405/0.778/0.595(0.592)
# Epoch 369 | KAN (loss/acc/sat): 0.405/0.778/0.595(0.593)
# Epoch 370 | KAN (loss/acc/sat): 0.405/0.778/0.595(0.593)
# Epoch 371 | KAN (loss/acc/sat): 0.405/0.778/0.595(0.593)
# Epoch 372 | KAN (loss/acc/sat): 0.404/0.778/0.596(0.593)
# Epoch 373 | KAN (loss/acc/sat): 0.404/0.778/0.596(0.594)
# Epoch 374 | KAN (loss/acc/sat): 0.404/0.779/0.596(0.594)
# Epoch 375 | KAN (loss/acc/sat): 0.403/0.779/0.597(0.594)
# Epoch 376 | KAN (loss/acc/sat): 0.403/0.779/0.597(0.595)
# Epoch 377 | KAN (loss/acc/sat): 0.403/0.779/0.597(0.595)
# Epoch 378 | KAN (loss/acc/sat): 0.402/0.780/0.598(0.595)
# Epoch 379 | KAN (loss/acc/sat): 0.402/0.780/0.598(0.596)
# Epoch 380 | KAN (loss/acc/sat): 0.402/0.781/0.598(0.596)
# Epoch 381 | KAN (loss/acc/sat): 0.401/0.780/0.599(0.596)
# Epoch 382 | KAN (loss/acc/sat): 0.401/0.780/0.599(0.596)
# Epoch 383 | KAN (loss/acc/sat): 0.401/0.780/0.599(0.597)
# Epoch 384 | KAN (loss/acc/sat): 0.400/0.781/0.600(0.597)
# Epoch 385 | KAN (loss/acc/sat): 0.400/0.780/0.600(0.597)
# Epoch 386 | KAN (loss/acc/sat): 0.400/0.781/0.600(0.598)
# Epoch 387 | KAN (loss/acc/sat): 0.399/0.781/0.601(0.598)
# Epoch 388 | KAN (loss/acc/sat): 0.399/0.782/0.601(0.598)
# Epoch 389 | KAN (loss/acc/sat): 0.399/0.782/0.601(0.598)
# Epoch 390 | KAN (loss/acc/sat): 0.399/0.782/0.601(0.599)
# Epoch 391 | KAN (loss/acc/sat): 0.398/0.781/0.602(0.599)
# Epoch 392 | KAN (loss/acc/sat): 0.398/0.781/0.602(0.599)
# Epoch 393 | KAN (loss/acc/sat): 0.398/0.782/0.602(0.600)
# Epoch 394 | KAN (loss/acc/sat): 0.397/0.782/0.603(0.600)
# Epoch 395 | KAN (loss/acc/sat): 0.397/0.782/0.603(0.600)
# Epoch 396 | KAN (loss/acc/sat): 0.397/0.783/0.603(0.600)
# Epoch 397 | KAN (loss/acc/sat): 0.396/0.782/0.604(0.601)
# Epoch 398 | KAN (loss/acc/sat): 0.396/0.783/0.604(0.601)
# Epoch 399 | KAN (loss/acc/sat): 0.396/0.782/0.604(0.601)
# Epoch 400 | KAN (loss/acc/sat): 0.395/0.782/0.605(0.601)
# Training finished.

# %%
def load_model_state(infer_model, model_save_folder, model_name):
    """
    Load the model from disk.
    """
    checkpoint = torch.load(os.path.join(model_save_folder, model_name), 
                            map_location=device)
    infer_model.load_state_dict(checkpoint)
    infer_model.eval()
    return infer_model

# Load the model
hierarchical_logiKNet_infer = KAN(width=[18, 10, 6], grid=5, k=3, seed=42, device=device)
hierarchical_logiKNet_infer = load_model_state(hierarchical_logiKNet_infer, model_state_folder, 'hierarchical_logiKNet.pt')
# Test the model
with torch.no_grad():
    for data, labels in test_loader:
        logits = hierarchical_logiKNet_infer(data)
        preds = torch.argmax(logits, dim=1)
        print(f"Predictions: {preds}, Labels: {labels}")
        
        hierarchical_logiKNet_infer_acc = compute_accuracy(test_loader, hierarchical_logiKNet_infer)
        print(f"Test accuracy of the loaded model: {hierarchical_logiKNet_infer_acc.item()}")
        break
# Out:
# checkpoint directory created: ./model
# saving model version 0.0
# Predictions: tensor([2, 2, 0,  ..., 2, 4, 2]), Labels: tensor([2, 0, 0,  ..., 2, 4, 2])
# Test accuracy of the loaded model: 0.7824236154556274
# /tmp/ipykernel_1302988/4219946763.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(os.path.join(model_save_folder, model_name),
